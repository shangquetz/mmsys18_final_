# %%
import matplotlib.pyplot as plt
from PyEMD import EMD  # 补充导入EMD类
import numpy as np
import os
from pathlib import Path
from PyEMD import EMD
import torch
import torch.nn as nn
import torch.optim as optim



# 定义设备：如果有显卡就用 cuda，否则回退到 cpu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"当前运行设备: {device}")




list_average_od_pred_1s=[]
list_average_od_pred_2s=[]
list_average_od_pred_3s=[]
list_average_od_pred_4s=[]
list_average_od_pred_5s=[]
#os.chdir('...')
a=Path("D:\MMsys18_final\sampled_data")
for b in a.iterdir():
    globals()[f"{b.stem}_pred"]=[]
    print(f'现在对{b.stem}进行预测')
    if b.suffix in ('.csv', '.txt'):
        data = np.genfromtxt(b, delimiter=',', skip_header=1)
        # 读取文件
        # os.chdir("D:\H\sampled_data")
        # data = np.genfromtxt("2_Diner_fixations_sample.csv", delimiter=',')

        od_values_list = []
        list_average_od = []

        # 对xyz三轴划分测试集
        x = data[:, 0]
        split_point = int(len(x) * 0.7)
        test_data_x = x[split_point:]
        print(f'测试集x轴长度{test_data_x.shape}')

        y = data[:, 1]
        split_point = int(len(y) * 0.7)
        test_data_y = y[split_point:]
        print(f'测试集y轴长度{test_data_y.shape}')

        z = data[:, 2]
        split_point = int(len(z) * 0.7)
        test_data_z = z[split_point:]
        print(f'测试集z轴长度{test_data_z.shape}')

        # 初始化EMD对象
        emd = EMD(max_imfs=7)
        # 执行EMD分解
        imfs_x = emd(x)  # 假设signal是已经定义好的输入信号
        imfs_x = imfs_x[:, split_point:]
        # imfs_x_label=x[-450:]
        # imfs_x_label=imfs_x_label[None,...]
        # imfs_x_label=torch.from_numpy(imfs_x_label)
        print(f'imfs_x的形状{imfs_x.shape}')
        # print(f'label的形状{imfs_x_label.shape}')

        # list_x_label=[]

        imfs_y = emd(y)
        imfs_y = imfs_y[:, split_point:]
        # imfs_y_label=y[-450:]
        # imfs_y_label=imfs_y_label[None,...]
        # imfs_y_label=torch.from_numpy(imfs_y_label)
        print(f'imfs_y的形状{imfs_y.shape}')
        # print(f'label的形状{imfs_y_label.shape}')

        # list_y_label=[]

        imfs_z = emd(z)
        imfs_z = imfs_z[:, split_point:]
        # imfs_z_label=z[-450:]
        # imfs_z_label=imfs_z_label[None,...]
        # imfs_z_label=torch.from_numpy(imfs_z_label)
        print(f'imfs_z的形状{imfs_z.shape}')
        # print(f'label的形状{imfs_z_label.shape}')

        # list_z_label=[]
        model_folder_name=b.name[:-4]+'_model'

        os.chdir(fr"D:\MMsys18_final\save_model\{model_folder_name}")
        for index in range(5):
            print(f'现在对{index + 1}s进行预测')

            os.chdir(fr"D:\MMsys18_final\save_model\{model_folder_name}\model_save_{index + 1}s")
            # 真实值采用滑动窗口对齐数据规模
            window_size_label = (index + 1) * 90


            def windows_label(a):
                samples = []
                for i in range(90, len(a) - window_size_label + 1):
                    samples.append(a[i:i + window_size_label])
                data_2d = np.array(samples)
                return data_2d


            # 真实值转换为tensor
            def transform_label(IMF):
                data_2d = windows_label(IMF)
                tensor = torch.from_numpy(data_2d)
                tensor_32_y_pred = tensor.float()
                return tensor_32_y_pred


            # 输入值滑动窗口

            window_size = 90


            def windows(a):
                window_size = 90
                samples = []
                for i in range(len(a) - window_size - window_size_label + 1):
                    samples.append(a[i:i + window_size])
                data_2d = np.array(samples)
                return data_2d


            # IMF转换为符合LSTM输入的三阶张量
            def transform(IMF):
                data_2d = windows(IMF)
                data_3d = data_2d[..., None]
                tensor = torch.from_numpy(data_3d)
                tensor_32 = tensor.float()
                return tensor_32


            tensor_32_label_x = transform_label(test_data_x)
            tensor_32_label_x = tensor_32_label_x.to(device)
            print(f'x轴真实情况{tensor_32_label_x.shape}')

            tensor_32_label_y = transform_label(test_data_y)
            tensor_32_label_y = tensor_32_label_y.to(device)
            print(f'y轴真实情况{tensor_32_label_y.shape}')

            tensor_32_label_z = transform_label(test_data_z)
            tensor_32_label_z = tensor_32_label_z.to(device)
            print(f'z轴真实情况{tensor_32_label_z.shape}')


            class ViewportPredictor(nn.Module):
                def __init__(self, input_dim, hidden_dim, horizon_H):
                    super(ViewportPredictor, self).__init__()

                    # --- 1. 双层堆叠 LSTM 部分 ---
                    self.lstm1 = nn.LSTM(input_dim, hidden_dim, batch_first=True)
                    self.lstm2 = nn.LSTM(hidden_dim, hidden_dim, batch_first=True)

                    # --- 2. 预测融合模块 (三层 MLP) ---
                    # 输入是 h' 和 c' 的拼接，维度为 hidden_dim * 2
                    self.tanh = nn.Tanh()
                    self.relu = nn.ReLU()

                    # 公式 (11) & (12) 的三层 MLP 结构
                    self.full_a = nn.Linear(hidden_dim * 2, 128)  # 升维
                    self.full_b = nn.Linear(128, 256)  # 中间层
                    self.full_c = nn.Linear(256, (index + 1) * 90)  # 映射到未来 H 时间段

                def forward(self, x):
                    # --- LSTM 层处理 (公式 8, 9) ---
                    output1, _ = self.lstm1(x)  # 第一层输出全序列 h
                    output2, (hn2, cn2) = self.lstm2(output1)  # 第二层接收 h，排除第一层的 c

                    # --- 特征提取 (公式 10) ---
                    h_last = hn2.squeeze(0)
                    c_last = cn2.squeeze(0)
                    combined = torch.cat((h_last, c_last), dim=1)  # h' ⊕ C'
                    pm_i_h = self.tanh(combined)  # 初始融合特征

                    # --- 三层 MLP 预测 (公式 11, 12) ---
                    # 第一层: ReLU(Full_a)dioaca
                    x_mlp = self.relu(self.full_a(pm_i_h))
                    # 第二层: ReLU(Full_b)
                    x_mlp = self.relu(self.full_b(x_mlp))
                    # 第三层: Linear(Full_c) -> 得到未来 H 的轨迹
                    prediction_h = self.full_c(x_mlp)

                    return prediction_h


            # 创建空列表
            list_x = []
            list_y = []
            list_z = []

            # 预测x轴
            print('开始预测x轴')


            def transform_1d_3d(IMF):
                data_2d = IMF[None, ...]
                data_3d = data_2d[..., None]
                tensor = torch.from_numpy(data_3d)
                tensor_32 = tensor.float()
                return tensor_32


            for i in range(len(imfs_x)):
                # 1. 直接加载整个模型文件
                model = torch.load(f'complete_model_x_pred_{index + 1}s_{i + 1}',weights_only=False)
                # 2. 切换到评估模式（依然非常重要！）
                model.eval()
                model.to(device)

                IMF_x = imfs_x[i, :]
                # print(IMF_x.shape)
                tensor_32 = transform(IMF_x)
                tensor_32 = tensor_32.to(device)
                # print(tensor_32.shape)
                # tensor_32_label=transform_label(IMF_x)
                # tensor_32_label=tensor_32_label.to(device)
                # list_x_label.append(tensor_32_label)

                outputs = model(tensor_32)

                print(f'此时预测imf{i + 1}输出形状{outputs.shape}')
                # print(f'采用的模型complete_model_x{i+1}___{model}')
                # print(outputs.shape)
                # print(outputs)

                list_x.append(outputs)
            # list_x_label=torch.cat(list_x_label,dim=0)
            list_2d_x = torch.sum(torch.stack(list_x), dim=0)
            print('x轴最终预测结果')
            print(f'x轴预测形状{list_2d_x.shape}')
            # print(f'x轴真实情况{list_x_label.shape}')
            print(list_2d_x)

            # 预测y轴
            print('-------------------------------')
            print('开始预测y轴')
            for i in range(len(imfs_y)):
                # 1. 直接加载整个模型文件
                model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
                # 2. 切换到评估模式（依然非常重要！）
                model.eval()
                model.to(device)

                IMF_y = imfs_y[i, :]
                tensor_32 = transform(IMF_y)
                tensor_32 = tensor_32.to(device)
                # tensor_32_label=transform_label(IMF_y)
                # tensor_32_label=tensor_32_label.to(device)

                outputs = model(tensor_32)

                print(f'此时预测imf{i + 1}输出形状{outputs.shape}')
                # print(f'采用的模型complete_model_y{i+1}___{model}')
                # print(outputs.shape)
                # print(outputs)

                list_y.append(outputs)
            list_2d_y = torch.sum(torch.stack(list_y), dim=0)
            print('y轴最终预测结果')
            print(f'y轴预测形状{list_2d_y.shape}')
            print(list_2d_y)

            print('-------------------------------------')
            print('开始预测z轴')
            for i in range(len(imfs_z)):
                # 1. 直接加载整个模型文件
                model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
                # 2. 切换到评估模式（依然非常重要！）
                model.eval()
                model.to(device)

                IMF_z = imfs_z[i, :]
                tensor_32 = transform(IMF_z)
                tensor_32 = tensor_32.to(device)
                # tensor_32_label=transform_label(IMF_z)
                # tensor_32_label=tensor_32_label.to(device)

                outputs = model(tensor_32)

                print(f'此时预测imf{i + 1}输出形状{outputs.shape}')
                # print(f'采用的模型complete_model_z{i+1}___{model}')
                # print(outputs.shape)
                # print(outputs)

                list_z.append(outputs)
            list_2d_z = torch.sum(torch.stack(list_z), dim=0)
            print('z轴最终预测结果')
            print(f'z轴预测形状{list_2d_z.shape}')
            print(list_2d_z)

            # 真实值和预测值组成列表
            # list_label=torch.cat([imfs_x_label,imfs_y_label,imfs_z_label],dim=0)
            # list_label=list_label.to(device)
            # print(f'真实标签形状{list_label.shape}')
            # print(f'真实标签数据{list_label}')
            # list_pred=torch.cat([list_2d_x,list_2d_y,list_2d_z],dim=0)
            # list_pred=list_pred.to(device)
            # print(f'预测形状{list_pred.shape}')
            # print(f'预测数据{list_pred}')

            # 评估（采用OD来写）
            for row in range(len(test_data_x) - window_size - window_size_label + 1):
                for i in range(window_size_label):
                    # 2. 从拼接后的张量中切片取出对应的分量
                    x1, y1, z1 = tensor_32_label_x[row, i], tensor_32_label_y[row, i], tensor_32_label_z[row, i]
                    x2, y2, z2 = list_2d_x[row, i], list_2d_y[row, i], list_2d_z[row, i]
                    # 3. 按照公式计算点积 (Dot Product)
                    # Formula: x1*x2 + y1*y2 + z1*z2

                    dot_product = x1 * x2 + y1 * y2 + z1 * z2

                    # 4. 数值安全处理：acos 的输入必须在 [-1, 1] 之间，否则会产生 NaN
                    dot_product = torch.clamp(dot_product, -1.0, 1.0)
                    # 5. 计算最终的 OD (即 arccos)
                    od_values = torch.acos(dot_product)
                    od_values_list.append(od_values.item())
            average_od = sum(od_values_list) / (
                        (len(test_data_x) - window_size - window_size_label + 1) * window_size_label)
            print(f'数据集大小{((len(test_data_x) - window_size - window_size_label + 1) * window_size_label)}')
            # print(f'计算得到的 OD 序列形状: {od_values_list.shape}') # 形状应该是 (N,)
            # print(f'最终得到的OD序列{od_values_list.shape}')
            print(f'{model_folder_name}_{index + 1}s平均误差{average_od}')

            globals()[f"{b.stem}_pred"].append(average_od)


            if index==0:
                list_average_od_pred_1s.append(average_od)
            elif index==1:
                list_average_od_pred_2s.append(average_od)
            elif index==2:
                list_average_od_pred_3s.append(average_od)
            elif index==3:
                list_average_od_pred_4s.append(average_od)
            elif index==4:
                list_average_od_pred_5s.append(average_od)



        plt.figure(figsize=(10, 5))
        plt.plot(globals()[f"{b.stem}_pred"], label='average_od', color='red', linewidth=2)
        plt.title(f'Visualization_average_od_{b.stem}')
        plt.xlabel('second')
        plt.xticks(ticks=range(len(globals()[f"{b.stem}_pred"])), labels=range(1, len(globals()[f"{b.stem}_pred"])+1))
        plt.ylabel('average_od')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.savefig(fr"D:\MMsys18_final\save_figure\{b.stem}_figure.png")
        plt.show()


average_pred_1s=sum(list_average_od_pred_1s)/len(list_average_od_pred_1s)
average_pred_2s=sum(list_average_od_pred_2s)/len(list_average_od_pred_2s)
average_pred_3s=sum(list_average_od_pred_3s)/len(list_average_od_pred_3s)
average_pred_4s=sum(list_average_od_pred_4s)/len(list_average_od_pred_4s)
average_pred_5s=sum(list_average_od_pred_5s)/len(list_average_od_pred_5s)
average_pred_1s_5s=[average_pred_1s,average_pred_2s,average_pred_3s,average_pred_4s,average_pred_5s]

plt.figure(figsize=(10, 5))
plt.plot(average_pred_1s_5s, label='average_od', color='red', linewidth=2)
plt.title('Visualization_average_od_sum')
plt.xlabel('second')
plt.xticks(ticks=range(len(average_pred_1s_5s)),labels=range(1,len(average_pred_1s_5s)+1))
plt.ylabel('average_od')
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig(fr"D:\MMsys18_final\save_figure\sum_figure.png")
plt.show()
# 假设你的 od_values_list 已经计算完成

# plt.figure(figsize=(10, 5))
# plt.plot(od_values_list, label='Orientation Distance (OD)', color='blue', linewidth=1)
# plt.axhline(y=0, color='r', linestyle='--', label='Perfect Alignment (OD=0)')  # 参考线

# plt.title('Visualization of OD Values')
# plt.xlabel('Sample Index')
# plt.ylabel('Angle (Radians)')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.show()
# Out:
# 当前运行设备: cuda
# 现在对10_Cows_fixations_sample进行预测
# 测试集x轴长度(1710,)
# 测试集y轴长度(1710,)
# 测试集z轴长度(1710,)
# imfs_x的形状(11, 1710)
# imfs_y的形状(10, 1710)
# imfs_z的形状(10, 1710)
# 现在对1s进行预测
# x轴真实情况torch.Size([1531, 90])
# y轴真实情况torch.Size([1531, 90])
# z轴真实情况torch.Size([1531, 90])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# x轴最终预测结果
# x轴预测形状torch.Size([1531, 90])
# tensor([[0.5863, 0.5750, 0.5666,  ..., 0.6682, 0.6850, 0.6749],
#         [0.5719, 0.5649, 0.5619,  ..., 0.6713, 0.6888, 0.6781],
#         [0.5642, 0.5618, 0.5641,  ..., 0.6743, 0.6919, 0.6815],
#         ...,
#         [0.4228, 0.4363, 0.4795,  ..., 0.6684, 0.6858, 0.6773],
#         [0.4534, 0.4745, 0.5189,  ..., 0.6695, 0.6854, 0.6761],
#         [0.4786, 0.5093, 0.5488,  ..., 0.6747, 0.6852, 0.6773]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# y轴最终预测结果
# y轴预测形状torch.Size([1531, 90])
# tensor([[0.4952, 0.4971, 0.5063,  ..., 0.4212, 0.4121, 0.4220],
#         [0.4987, 0.5077, 0.5219,  ..., 0.4251, 0.4170, 0.4256],
#         [0.5200, 0.5317, 0.5456,  ..., 0.4293, 0.4225, 0.4300],
#         ...,
#         [0.9289, 0.9069, 0.8372,  ..., 0.4699, 0.4837, 0.4852],
#         [0.8902, 0.8773, 0.8267,  ..., 0.4830, 0.4959, 0.4943],
#         [0.8247, 0.8156, 0.7822,  ..., 0.4941, 0.5035, 0.5054]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24160\880397507.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24160\880397507.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# z轴最终预测结果
# z轴预测形状torch.Size([1531, 90])
# tensor([[0.6348, 0.6271, 0.6198,  ..., 0.5299, 0.5173, 0.5258],
#         [0.6458, 0.6354, 0.6261,  ..., 0.5280, 0.5160, 0.5267],
#         [0.6486, 0.6378, 0.6271,  ..., 0.5271, 0.5157, 0.5262],
#         ...,
#         [0.4946, 0.4939, 0.4965,  ..., 0.4788, 0.4784, 0.4808],
#         [0.4986, 0.4981, 0.5008,  ..., 0.4783, 0.4777, 0.4803],
#         [0.5011, 0.5007, 0.5035,  ..., 0.4778, 0.4770, 0.4799]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小137790
# 10_Cows_fixations_sample_model_1s平均误差0.19370494180452338
# 现在对2s进行预测
# x轴真实情况torch.Size([1441, 180])
# y轴真实情况torch.Size([1441, 180])
# z轴真实情况torch.Size([1441, 180])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# x轴最终预测结果
# x轴预测形状torch.Size([1441, 180])
# tensor([[0.6038, 0.6112, 0.6091,  ..., 0.6829, 0.6762, 0.6834],
#         [0.5975, 0.6089, 0.6120,  ..., 0.6863, 0.6797, 0.6865],
#         [0.5965, 0.6131, 0.6222,  ..., 0.6898, 0.6835, 0.6893],
#         ...,
#         [0.7586, 0.7731, 0.7761,  ..., 0.7101, 0.7025, 0.7088],
#         [0.7623, 0.7787, 0.7842,  ..., 0.7096, 0.7022, 0.7086],
#         [0.7747, 0.7913, 0.7974,  ..., 0.7084, 0.7011, 0.7071]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# y轴最终预测结果
# y轴预测形状torch.Size([1441, 180])
# tensor([[0.5511, 0.5778, 0.5932,  ..., 0.5225, 0.5198, 0.5325],
#         [0.5617, 0.5933, 0.6135,  ..., 0.5180, 0.5160, 0.5280],
#         [0.5837, 0.6162, 0.6368,  ..., 0.5138, 0.5122, 0.5234],
#         ...,
#         [0.4494, 0.4322, 0.4005,  ..., 0.4583, 0.4521, 0.4608],
#         [0.4235, 0.4047, 0.3723,  ..., 0.4625, 0.4558, 0.4643],
#         [0.3831, 0.3682, 0.3422,  ..., 0.4652, 0.4587, 0.4668]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# z轴最终预测结果
# z轴预测形状torch.Size([1441, 180])
# tensor([[0.5849, 0.5911, 0.5804,  ..., 0.4770, 0.4786, 0.4758],
#         [0.6006, 0.6031, 0.5878,  ..., 0.4751, 0.4777, 0.4745],
#         [0.6088, 0.6092, 0.5921,  ..., 0.4744, 0.4776, 0.4742],
#         ...,
#         [0.5047, 0.4994, 0.4998,  ..., 0.5054, 0.5079, 0.5024],
#         [0.4998, 0.4938, 0.4934,  ..., 0.5050, 0.5075, 0.5022],
#         [0.4941, 0.4871, 0.4860,  ..., 0.5043, 0.5069, 0.5018]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小259380
# 10_Cows_fixations_sample_model_2s平均误差0.35125836171002633
# 现在对3s进行预测
# x轴真实情况torch.Size([1351, 270])
# y轴真实情况torch.Size([1351, 270])
# z轴真实情况torch.Size([1351, 270])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# x轴最终预测结果
# x轴预测形状torch.Size([1351, 270])
# tensor([[0.5887, 0.5853, 0.5841,  ..., 0.6989, 0.6908, 0.6954],
#         [0.5759, 0.5768, 0.5802,  ..., 0.6962, 0.6887, 0.6917],
#         [0.5696, 0.5756, 0.5838,  ..., 0.6927, 0.6865, 0.6877],
#         ...,
#         [0.9064, 0.9057, 0.8878,  ..., 0.6945, 0.6932, 0.6931],
#         [0.9074, 0.8958, 0.8708,  ..., 0.6970, 0.6920, 0.6925],
#         [0.8764, 0.8611, 0.8367,  ..., 0.6988, 0.6894, 0.6927]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# y轴最终预测结果
# y轴预测形状torch.Size([1351, 270])
# tensor([[0.5022, 0.4934, 0.4817,  ..., 0.5349, 0.5351, 0.5331],
#         [0.5116, 0.5099, 0.5047,  ..., 0.5332, 0.5341, 0.5320],
#         [0.5314, 0.5334, 0.5309,  ..., 0.5311, 0.5325, 0.5307],
#         ...,
#         [0.3438, 0.4208, 0.4920,  ..., 0.5119, 0.5241, 0.5291],
#         [0.3574, 0.4390, 0.5098,  ..., 0.5106, 0.5203, 0.5214],
#         [0.4134, 0.4924, 0.5546,  ..., 0.5106, 0.5194, 0.5159]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# z轴最终预测结果
# z轴预测形状torch.Size([1351, 270])
# tensor([[0.5756, 0.5757, 0.5652,  ..., 0.4896, 0.4909, 0.4877],
#         [0.5881, 0.5876, 0.5747,  ..., 0.4902, 0.4910, 0.4884],
#         [0.5956, 0.5949, 0.5808,  ..., 0.4906, 0.4909, 0.4890],
#         ...,
#         [0.4659, 0.4626, 0.4610,  ..., 0.4915, 0.4918, 0.4923],
#         [0.4672, 0.4639, 0.4623,  ..., 0.4908, 0.4912, 0.4916],
#         [0.4691, 0.4659, 0.4645,  ..., 0.4902, 0.4906, 0.4909]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小364770
# 10_Cows_fixations_sample_model_3s平均误差0.49298881412107753
# 现在对4s进行预测
# x轴真实情况torch.Size([1261, 360])
# y轴真实情况torch.Size([1261, 360])
# z轴真实情况torch.Size([1261, 360])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# x轴最终预测结果
# x轴预测形状torch.Size([1261, 360])
# tensor([[0.6769, 0.6848, 0.6732,  ..., 0.7003, 0.6999, 0.6915],
#         [0.6575, 0.6685, 0.6597,  ..., 0.7008, 0.7007, 0.6922],
#         [0.6437, 0.6584, 0.6530,  ..., 0.7013, 0.7018, 0.6932],
#         ...,
#         [0.7700, 0.7683, 0.7509,  ..., 0.6940, 0.6953, 0.6905],
#         [0.7606, 0.7590, 0.7421,  ..., 0.6946, 0.6964, 0.6913],
#         [0.7477, 0.7472, 0.7324,  ..., 0.6954, 0.6974, 0.6921]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# y轴最终预测结果
# y轴预测形状torch.Size([1261, 360])
# tensor([[0.4704, 0.4766, 0.4782,  ..., 0.5211, 0.5251, 0.5228],
#         [0.4810, 0.4935, 0.4993,  ..., 0.5206, 0.5241, 0.5206],
#         [0.5054, 0.5210, 0.5276,  ..., 0.5191, 0.5221, 0.5181],
#         ...,
#         [0.4774, 0.4794, 0.4743,  ..., 0.5435, 0.5668, 0.5553],
#         [0.4950, 0.4985, 0.4941,  ..., 0.5439, 0.5689, 0.5559],
#         [0.5188, 0.5221, 0.5195,  ..., 0.5442, 0.5706, 0.5559]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# z轴最终预测结果
# z轴预测形状torch.Size([1261, 360])
# tensor([[0.5086, 0.5002, 0.5040,  ..., 0.5002, 0.4917, 0.4914],
#         [0.5191, 0.5101, 0.5116,  ..., 0.5008, 0.4919, 0.4917],
#         [0.5276, 0.5178, 0.5179,  ..., 0.5012, 0.4924, 0.4922],
#         ...,
#         [0.4788, 0.4758, 0.4795,  ..., 0.4924, 0.4882, 0.4832],
#         [0.4791, 0.4759, 0.4796,  ..., 0.4925, 0.4883, 0.4833],
#         [0.4793, 0.4760, 0.4798,  ..., 0.4925, 0.4884, 0.4834]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小453960
# 10_Cows_fixations_sample_model_4s平均误差0.6608139799082147
# 现在对5s进行预测
# x轴真实情况torch.Size([1171, 450])
# y轴真实情况torch.Size([1171, 450])
# z轴真实情况torch.Size([1171, 450])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# x轴最终预测结果
# x轴预测形状torch.Size([1171, 450])
# tensor([[0.6007, 0.5941, 0.5989,  ..., 0.6755, 0.6853, 0.6709],
#         [0.5917, 0.5883, 0.5965,  ..., 0.6750, 0.6831, 0.6693],
#         [0.5888, 0.5890, 0.6015,  ..., 0.6747, 0.6810, 0.6676],
#         ...,
#         [0.6666, 0.6699, 0.6795,  ..., 0.6741, 0.6785, 0.6608],
#         [0.6773, 0.6802, 0.6882,  ..., 0.6719, 0.6767, 0.6588],
#         [0.6898, 0.6924, 0.6996,  ..., 0.6695, 0.6742, 0.6566]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# y轴最终预测结果
# y轴预测形状torch.Size([1171, 450])
# tensor([[0.5380, 0.5202, 0.5153,  ..., 0.4906, 0.4890, 0.4895],
#         [0.5510, 0.5386, 0.5375,  ..., 0.4910, 0.4889, 0.4891],
#         [0.5674, 0.5574, 0.5575,  ..., 0.4926, 0.4893, 0.4900],
#         ...,
#         [0.5900, 0.5711, 0.5534,  ..., 0.5126, 0.5102, 0.5105],
#         [0.5820, 0.5641, 0.5474,  ..., 0.5134, 0.5110, 0.5113],
#         [0.5724, 0.5553, 0.5394,  ..., 0.5143, 0.5120, 0.5124]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# z轴最终预测结果
# z轴预测形状torch.Size([1171, 450])
# tensor([[0.5008, 0.5113, 0.5040,  ..., 0.5050, 0.5043, 0.5058],
#         [0.5122, 0.5237, 0.5125,  ..., 0.5060, 0.5066, 0.5074],
#         [0.5206, 0.5320, 0.5185,  ..., 0.5072, 0.5086, 0.5091],
#         ...,
#         [0.4291, 0.4327, 0.4277,  ..., 0.4680, 0.4779, 0.4735],
#         [0.4269, 0.4320, 0.4262,  ..., 0.4672, 0.4769, 0.4724],
#         [0.4247, 0.4314, 0.4249,  ..., 0.4664, 0.4760, 0.4713]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小526950
# 10_Cows_fixations_sample_model_5s平均误差0.8503525390297125
# 现在对11_Abbottsford_fixations_sample进行预测
# 测试集x轴长度(1710,)
# 测试集y轴长度(1710,)
# 测试集z轴长度(1710,)
# imfs_x的形状(11, 1710)
# imfs_y的形状(12, 1710)
# imfs_z的形状(10, 1710)
# 现在对1s进行预测
# x轴真实情况torch.Size([1531, 90])
# y轴真实情况torch.Size([1531, 90])
# z轴真实情况torch.Size([1531, 90])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# x轴最终预测结果
# x轴预测形状torch.Size([1531, 90])
# tensor([[0.8073, 0.8118, 0.8029,  ..., 0.7241, 0.7224, 0.7170],
#         [0.8079, 0.8123, 0.8039,  ..., 0.7241, 0.7226, 0.7173],
#         [0.8091, 0.8131, 0.8049,  ..., 0.7244, 0.7228, 0.7177],
#         ...,
#         [0.8109, 0.8190, 0.8221,  ..., 0.7077, 0.7053, 0.7020],
#         [0.8082, 0.8159, 0.8171,  ..., 0.7096, 0.7072, 0.7039],
#         [0.8058, 0.8130, 0.8115,  ..., 0.7120, 0.7096, 0.7065]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# 此时预测imf12输出形状torch.Size([1531, 90])
# y轴最终预测结果
# y轴预测形状torch.Size([1531, 90])
# tensor([[0.3808, 0.3672, 0.3674,  ..., 0.3370, 0.3378, 0.3422],
#         [0.3832, 0.3703, 0.3699,  ..., 0.3363, 0.3368, 0.3418],
#         [0.3846, 0.3724, 0.3717,  ..., 0.3359, 0.3361, 0.3418],
#         ...,
#         [0.3660, 0.3397, 0.3371,  ..., 0.3832, 0.3814, 0.3856],
#         [0.3677, 0.3395, 0.3366,  ..., 0.3824, 0.3809, 0.3850],
#         [0.3687, 0.3385, 0.3350,  ..., 0.3809, 0.3793, 0.3837]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24160\880397507.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24160\880397507.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# z轴最终预测结果
# z轴预测形状torch.Size([1531, 90])
# tensor([[0.4481, 0.4458, 0.4467,  ..., 0.5307, 0.5329, 0.5297],
#         [0.4445, 0.4420, 0.4435,  ..., 0.5311, 0.5333, 0.5301],
#         [0.4417, 0.4391, 0.4411,  ..., 0.5320, 0.5339, 0.5308],
#         ...,
#         [0.4132, 0.4223, 0.4303,  ..., 0.5695, 0.5725, 0.5673],
#         [0.4204, 0.4278, 0.4343,  ..., 0.5690, 0.5730, 0.5670],
#         [0.4305, 0.4366, 0.4421,  ..., 0.5680, 0.5728, 0.5662]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小137790
# 11_Abbottsford_fixations_sample_model_1s平均误差0.27984427222539293
# 现在对2s进行预测
# x轴真实情况torch.Size([1441, 180])
# y轴真实情况torch.Size([1441, 180])
# z轴真实情况torch.Size([1441, 180])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# x轴最终预测结果
# x轴预测形状torch.Size([1441, 180])
# tensor([[0.8180, 0.8204, 0.8266,  ..., 0.7045, 0.7052, 0.7021],
#         [0.8179, 0.8202, 0.8267,  ..., 0.7043, 0.7048, 0.7021],
#         [0.8166, 0.8188, 0.8258,  ..., 0.7042, 0.7046, 0.7023],
#         ...,
#         [0.7533, 0.7404, 0.7186,  ..., 0.6951, 0.6982, 0.6958],
#         [0.7151, 0.7077, 0.6951,  ..., 0.6965, 0.7008, 0.6979],
#         [0.6810, 0.6804, 0.6771,  ..., 0.6982, 0.7025, 0.6987]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# 此时预测imf12输出形状torch.Size([1441, 180])
# y轴最终预测结果
# y轴预测形状torch.Size([1441, 180])
# tensor([[0.3994, 0.4075, 0.4099,  ..., 0.3656, 0.3719, 0.3653],
#         [0.4028, 0.4112, 0.4142,  ..., 0.3674, 0.3736, 0.3671],
#         [0.4057, 0.4144, 0.4181,  ..., 0.3690, 0.3752, 0.3689],
#         ...,
#         [0.1046, 0.0807, 0.0574,  ..., 0.3744, 0.3638, 0.3640],
#         [0.0980, 0.0707, 0.0463,  ..., 0.3648, 0.3560, 0.3517],
#         [0.0871, 0.0587, 0.0325,  ..., 0.3560, 0.3490, 0.3400]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# z轴最终预测结果
# z轴预测形状torch.Size([1441, 180])
# tensor([[0.4515, 0.4485, 0.4506,  ..., 0.5064, 0.5032, 0.5049],
#         [0.4470, 0.4441, 0.4465,  ..., 0.5067, 0.5035, 0.5052],
#         [0.4425, 0.4398, 0.4424,  ..., 0.5072, 0.5039, 0.5057],
#         ...,
#         [0.6670, 0.6668, 0.6557,  ..., 0.5273, 0.5283, 0.5267],
#         [0.6782, 0.6745, 0.6607,  ..., 0.5290, 0.5287, 0.5264],
#         [0.6846, 0.6767, 0.6596,  ..., 0.5304, 0.5288, 0.5265]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小259380
# 11_Abbottsford_fixations_sample_model_2s平均误差0.47684134566282405
# 现在对3s进行预测
# x轴真实情况torch.Size([1351, 270])
# y轴真实情况torch.Size([1351, 270])
# z轴真实情况torch.Size([1351, 270])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# x轴最终预测结果
# x轴预测形状torch.Size([1351, 270])
# tensor([[0.8196, 0.8124, 0.8156,  ..., 0.7005, 0.7033, 0.7011],
#         [0.8180, 0.8106, 0.8139,  ..., 0.7011, 0.7034, 0.7012],
#         [0.8168, 0.8092, 0.8122,  ..., 0.7012, 0.7029, 0.7010],
#         ...,
#         [0.7026, 0.6990, 0.7077,  ..., 0.7022, 0.7045, 0.7035],
#         [0.7014, 0.7026, 0.7155,  ..., 0.7023, 0.7041, 0.7023],
#         [0.7020, 0.7080, 0.7258,  ..., 0.7021, 0.7038, 0.7010]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# 此时预测imf12输出形状torch.Size([1351, 270])
# y轴最终预测结果
# y轴预测形状torch.Size([1351, 270])
# tensor([[0.3244, 0.3360, 0.3424,  ..., 0.3805, 0.3813, 0.3789],
#         [0.3249, 0.3371, 0.3444,  ..., 0.3810, 0.3818, 0.3793],
#         [0.3256, 0.3386, 0.3470,  ..., 0.3815, 0.3824, 0.3798],
#         ...,
#         [0.1400, 0.1680, 0.1917,  ..., 0.4681, 0.4564, 0.4625],
#         [0.1321, 0.1582, 0.1781,  ..., 0.4639, 0.4526, 0.4589],
#         [0.1228, 0.1464, 0.1627,  ..., 0.4601, 0.4491, 0.4560]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# z轴最终预测结果
# z轴预测形状torch.Size([1351, 270])
# tensor([[0.4543, 0.4588, 0.4570,  ..., 0.5247, 0.5216, 0.5207],
#         [0.4508, 0.4549, 0.4532,  ..., 0.5252, 0.5222, 0.5211],
#         [0.4474, 0.4513, 0.4497,  ..., 0.5259, 0.5227, 0.5215],
#         ...,
#         [0.6922, 0.7047, 0.7043,  ..., 0.5032, 0.5018, 0.5012],
#         [0.7006, 0.7095, 0.7058,  ..., 0.5028, 0.5025, 0.5017],
#         [0.7063, 0.7115, 0.7039,  ..., 0.5030, 0.5037, 0.5023]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小364770
# 11_Abbottsford_fixations_sample_model_3s平均误差0.6787476004307033
# 现在对4s进行预测
# x轴真实情况torch.Size([1261, 360])
# y轴真实情况torch.Size([1261, 360])
# z轴真实情况torch.Size([1261, 360])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# x轴最终预测结果
# x轴预测形状torch.Size([1261, 360])
# tensor([[0.8096, 0.8080, 0.8026,  ..., 0.7353, 0.7376, 0.7387],
#         [0.8087, 0.8071, 0.8019,  ..., 0.7343, 0.7369, 0.7379],
#         [0.8067, 0.8051, 0.8003,  ..., 0.7335, 0.7363, 0.7370],
#         ...,
#         [0.8012, 0.8159, 0.8400,  ..., 0.7305, 0.7362, 0.7394],
#         [0.8014, 0.8190, 0.8453,  ..., 0.7275, 0.7345, 0.7375],
#         [0.8083, 0.8272, 0.8509,  ..., 0.7256, 0.7328, 0.7354]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# 此时预测imf12输出形状torch.Size([1261, 360])
# y轴最终预测结果
# y轴预测形状torch.Size([1261, 360])
# tensor([[ 0.3910,  0.3972,  0.4051,  ...,  0.3987,  0.4061,  0.4004],
#         [ 0.3906,  0.3978,  0.4059,  ...,  0.3979,  0.4047,  0.3988],
#         [ 0.3899,  0.3985,  0.4071,  ...,  0.3969,  0.4030,  0.3971],
#         ...,
#         [ 0.0739,  0.0179, -0.0303,  ...,  0.3258,  0.3395,  0.3272],
#         [ 0.0188, -0.0358, -0.0775,  ...,  0.3281,  0.3363,  0.3297],
#         [-0.0098, -0.0583, -0.0935,  ...,  0.3306,  0.3358,  0.3358]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# z轴最终预测结果
# z轴预测形状torch.Size([1261, 360])
# tensor([[0.4448, 0.4457, 0.4419,  ..., 0.5260, 0.5188, 0.5200],
#         [0.4426, 0.4439, 0.4408,  ..., 0.5257, 0.5184, 0.5198],
#         [0.4406, 0.4427, 0.4405,  ..., 0.5253, 0.5180, 0.5196],
#         ...,
#         [0.4680, 0.4720, 0.4710,  ..., 0.5235, 0.5200, 0.5222],
#         [0.4695, 0.4738, 0.4731,  ..., 0.5237, 0.5202, 0.5225],
#         [0.4706, 0.4752, 0.4749,  ..., 0.5239, 0.5204, 0.5227]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小453960
# 11_Abbottsford_fixations_sample_model_4s平均误差0.8859499241890175
# 现在对5s进行预测
# x轴真实情况torch.Size([1171, 450])
# y轴真实情况torch.Size([1171, 450])
# z轴真实情况torch.Size([1171, 450])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# x轴最终预测结果
# x轴预测形状torch.Size([1171, 450])
# tensor([[0.8158, 0.8141, 0.8223,  ..., 0.7164, 0.7178, 0.7172],
#         [0.8155, 0.8144, 0.8223,  ..., 0.7167, 0.7182, 0.7176],
#         [0.8151, 0.8140, 0.8217,  ..., 0.7170, 0.7184, 0.7180],
#         ...,
#         [0.6111, 0.6401, 0.6444,  ..., 0.7327, 0.7315, 0.7311],
#         [0.6018, 0.6306, 0.6381,  ..., 0.7342, 0.7322, 0.7321],
#         [0.5941, 0.6215, 0.6314,  ..., 0.7359, 0.7329, 0.7333]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# 此时预测imf12输出形状torch.Size([1171, 450])
# y轴最终预测结果
# y轴预测形状torch.Size([1171, 450])
# tensor([[0.3935, 0.4077, 0.4184,  ..., 0.3784, 0.3773, 0.3723],
#         [0.3935, 0.4086, 0.4198,  ..., 0.3786, 0.3776, 0.3725],
#         [0.3932, 0.4093, 0.4214,  ..., 0.3789, 0.3778, 0.3726],
#         ...,
#         [0.5025, 0.5154, 0.5239,  ..., 0.3526, 0.3532, 0.3511],
#         [0.5031, 0.5174, 0.5267,  ..., 0.3505, 0.3513, 0.3483],
#         [0.5066, 0.5233, 0.5341,  ..., 0.3487, 0.3496, 0.3456]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# z轴最终预测结果
# z轴预测形状torch.Size([1171, 450])
# tensor([[0.4641, 0.4694, 0.4627,  ..., 0.5088, 0.5048, 0.5047],
#         [0.4605, 0.4659, 0.4599,  ..., 0.5086, 0.5044, 0.5046],
#         [0.4567, 0.4625, 0.4574,  ..., 0.5084, 0.5042, 0.5044],
#         ...,
#         [0.5881, 0.5866, 0.5723,  ..., 0.5014, 0.5020, 0.5008],
#         [0.5985, 0.5938, 0.5772,  ..., 0.5006, 0.5013, 0.5001],
#         [0.6080, 0.6000, 0.5812,  ..., 0.4998, 0.5011, 0.5000]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小526950
# 11_Abbottsford_fixations_sample_model_5s平均误差1.111238461914565
# 现在对12_TeatroRegioTorino_fixations_sample进行预测
# 测试集x轴长度(1710,)
# 测试集y轴长度(1710,)
# 测试集z轴长度(1710,)
# imfs_x的形状(11, 1710)
# imfs_y的形状(10, 1710)
# imfs_z的形状(10, 1710)
# 现在对1s进行预测
# x轴真实情况torch.Size([1531, 90])
# y轴真实情况torch.Size([1531, 90])
# z轴真实情况torch.Size([1531, 90])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# x轴最终预测结果
# x轴预测形状torch.Size([1531, 90])
# tensor([[0.8448, 0.8843, 0.8881,  ..., 0.7437, 0.7278, 0.7336],
#         [0.8467, 0.8834, 0.8868,  ..., 0.7480, 0.7288, 0.7323],
#         [0.8416, 0.8707, 0.8710,  ..., 0.7445, 0.7268, 0.7306],
#         ...,
#         [0.7392, 0.6919, 0.6468,  ..., 0.6981, 0.7002, 0.7073],
#         [0.6069, 0.5841, 0.5673,  ..., 0.6969, 0.6978, 0.7059],
#         [0.5249, 0.5184, 0.5195,  ..., 0.7007, 0.7012, 0.7070]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24160\880397507.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24160\880397507.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# y轴最终预测结果
# y轴预测形状torch.Size([1531, 90])
# tensor([[0.0994, 0.0864, 0.0794,  ..., 0.4232, 0.4135, 0.4119],
#         [0.1325, 0.1197, 0.1209,  ..., 0.4031, 0.3946, 0.3963],
#         [0.1809, 0.1679, 0.1788,  ..., 0.3873, 0.3793, 0.3847],
#         ...,
#         [0.2022, 0.2774, 0.3779,  ..., 0.3578, 0.3530, 0.3734],
#         [0.4318, 0.4670, 0.5455,  ..., 0.3769, 0.3698, 0.3886],
#         [0.6050, 0.6098, 0.6679,  ..., 0.3935, 0.3806, 0.3946]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# z轴最终预测结果
# z轴预测形状torch.Size([1531, 90])
# tensor([[0.5781, 0.5586, 0.5351,  ..., 0.4984, 0.4976, 0.5013],
#         [0.5958, 0.5709, 0.5441,  ..., 0.4993, 0.4994, 0.5023],
#         [0.6047, 0.5786, 0.5514,  ..., 0.4994, 0.4997, 0.5029],
#         ...,
#         [0.4952, 0.4832, 0.4878,  ..., 0.5049, 0.4972, 0.4952],
#         [0.5008, 0.4872, 0.4907,  ..., 0.5045, 0.4964, 0.4944],
#         [0.5039, 0.4901, 0.4936,  ..., 0.5038, 0.4952, 0.4933]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小137790
# 12_TeatroRegioTorino_fixations_sample_model_1s平均误差0.32365287834553286
# 现在对2s进行预测
# x轴真实情况torch.Size([1441, 180])
# y轴真实情况torch.Size([1441, 180])
# z轴真实情况torch.Size([1441, 180])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# x轴最终预测结果
# x轴预测形状torch.Size([1441, 180])
# tensor([[0.7973, 0.8184, 0.8452,  ..., 0.6767, 0.6725, 0.6848],
#         [0.7944, 0.8110, 0.8430,  ..., 0.6765, 0.6734, 0.6850],
#         [0.7821, 0.7915, 0.8270,  ..., 0.6779, 0.6719, 0.6840],
#         ...,
#         [0.7080, 0.6522, 0.5866,  ..., 0.7217, 0.7218, 0.7377],
#         [0.5728, 0.5352, 0.4955,  ..., 0.7190, 0.7165, 0.7320],
#         [0.4558, 0.4326, 0.4178,  ..., 0.7166, 0.7126, 0.7284]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# y轴最终预测结果
# y轴预测形状torch.Size([1441, 180])
# tensor([[0.1308, 0.0680, 0.0436,  ..., 0.4290, 0.4120, 0.4224],
#         [0.1730, 0.1214, 0.1027,  ..., 0.4294, 0.4164, 0.4252],
#         [0.2188, 0.1798, 0.1662,  ..., 0.4324, 0.4235, 0.4274],
#         ...,
#         [0.2801, 0.3644, 0.4218,  ..., 0.4031, 0.4044, 0.4182],
#         [0.5157, 0.5688, 0.5885,  ..., 0.4140, 0.4185, 0.4253],
#         [0.7201, 0.7357, 0.7079,  ..., 0.4220, 0.4264, 0.4282]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# z轴最终预测结果
# z轴预测形状torch.Size([1441, 180])
# tensor([[0.5370, 0.5449, 0.5394,  ..., 0.5100, 0.5120, 0.5185],
#         [0.5659, 0.5671, 0.5564,  ..., 0.5061, 0.5095, 0.5167],
#         [0.5878, 0.5806, 0.5668,  ..., 0.5070, 0.5112, 0.5172],
#         ...,
#         [0.4956, 0.4964, 0.4934,  ..., 0.5045, 0.5033, 0.5066],
#         [0.5047, 0.5074, 0.5060,  ..., 0.5045, 0.5033, 0.5070],
#         [0.5139, 0.5187, 0.5193,  ..., 0.5043, 0.5034, 0.5072]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小259380
# 12_TeatroRegioTorino_fixations_sample_model_2s平均误差0.47169279861056035
# 现在对3s进行预测
# x轴真实情况torch.Size([1351, 270])
# y轴真实情况torch.Size([1351, 270])
# z轴真实情况torch.Size([1351, 270])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# x轴最终预测结果
# x轴预测形状torch.Size([1351, 270])
# tensor([[0.8156, 0.8347, 0.8653,  ..., 0.6964, 0.7022, 0.6927],
#         [0.8156, 0.8366, 0.8612,  ..., 0.7004, 0.7067, 0.6991],
#         [0.8117, 0.8305, 0.8502,  ..., 0.7034, 0.7076, 0.7031],
#         ...,
#         [0.7287, 0.7254, 0.7279,  ..., 0.7022, 0.7047, 0.6999],
#         [0.7479, 0.7402, 0.7343,  ..., 0.7031, 0.7078, 0.7038],
#         [0.7621, 0.7518, 0.7374,  ..., 0.7059, 0.7120, 0.7085]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# y轴最终预测结果
# y轴预测形状torch.Size([1351, 270])
# tensor([[0.1419, 0.0844, 0.0594,  ..., 0.4182, 0.4215, 0.4335],
#         [0.1635, 0.1115, 0.1007,  ..., 0.4208, 0.4221, 0.4390],
#         [0.1857, 0.1453, 0.1464,  ..., 0.4257, 0.4307, 0.4427],
#         ...,
#         [0.5771, 0.5702, 0.5911,  ..., 0.4096, 0.4102, 0.4400],
#         [0.5959, 0.5961, 0.6146,  ..., 0.4339, 0.4340, 0.4509],
#         [0.6137, 0.6226, 0.6402,  ..., 0.4565, 0.4556, 0.4576]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# z轴最终预测结果
# z轴预测形状torch.Size([1351, 270])
# tensor([[0.5047, 0.5042, 0.5114,  ..., 0.5084, 0.5107, 0.5118],
#         [0.5204, 0.5148, 0.5175,  ..., 0.5061, 0.5080, 0.5107],
#         [0.5361, 0.5253, 0.5235,  ..., 0.5043, 0.5057, 0.5099],
#         ...,
#         [0.5030, 0.4965, 0.4986,  ..., 0.4950, 0.5010, 0.4978],
#         [0.4975, 0.4928, 0.4957,  ..., 0.4954, 0.5014, 0.4981],
#         [0.4923, 0.4895, 0.4933,  ..., 0.4959, 0.5018, 0.4984]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小364770
# 12_TeatroRegioTorino_fixations_sample_model_3s平均误差0.6670989488712509
# 现在对4s进行预测
# x轴真实情况torch.Size([1261, 360])
# y轴真实情况torch.Size([1261, 360])
# z轴真实情况torch.Size([1261, 360])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# x轴最终预测结果
# x轴预测形状torch.Size([1261, 360])
# tensor([[0.8309, 0.8471, 0.8696,  ..., 0.7611, 0.7663, 0.7554],
#         [0.8115, 0.8260, 0.8455,  ..., 0.7595, 0.7634, 0.7523],
#         [0.7935, 0.8028, 0.8175,  ..., 0.7571, 0.7593, 0.7492],
#         ...,
#         [0.7604, 0.7647, 0.7587,  ..., 0.7300, 0.7286, 0.7230],
#         [0.7546, 0.7583, 0.7518,  ..., 0.7293, 0.7283, 0.7231],
#         [0.7478, 0.7511, 0.7441,  ..., 0.7288, 0.7282, 0.7231]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# y轴最终预测结果
# y轴预测形状torch.Size([1261, 360])
# tensor([[0.1269, 0.0656, 0.0503,  ..., 0.3942, 0.3896, 0.4021],
#         [0.1433, 0.0829, 0.0788,  ..., 0.3942, 0.3987, 0.4055],
#         [0.1607, 0.1079, 0.1209,  ..., 0.3984, 0.4085, 0.4115],
#         ...,
#         [0.4538, 0.4669, 0.4543,  ..., 0.4368, 0.4300, 0.4253],
#         [0.4642, 0.4776, 0.4640,  ..., 0.4376, 0.4291, 0.4249],
#         [0.4734, 0.4888, 0.4754,  ..., 0.4398, 0.4294, 0.4252]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# z轴最终预测结果
# z轴预测形状torch.Size([1261, 360])
# tensor([[0.4808, 0.4850, 0.4804,  ..., 0.4950, 0.4958, 0.4991],
#         [0.5015, 0.5011, 0.4907,  ..., 0.4947, 0.4951, 0.4985],
#         [0.5199, 0.5158, 0.5002,  ..., 0.4942, 0.4943, 0.4983],
#         ...,
#         [0.4992, 0.5118, 0.5164,  ..., 0.4955, 0.4993, 0.5012],
#         [0.5017, 0.5136, 0.5180,  ..., 0.4952, 0.4991, 0.5005],
#         [0.5045, 0.5153, 0.5196,  ..., 0.4949, 0.4989, 0.4996]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小453960
# 12_TeatroRegioTorino_fixations_sample_model_4s平均误差0.8731786082610827
# 现在对5s进行预测
# x轴真实情况torch.Size([1171, 450])
# y轴真实情况torch.Size([1171, 450])
# z轴真实情况torch.Size([1171, 450])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# x轴最终预测结果
# x轴预测形状torch.Size([1171, 450])
# tensor([[0.9017, 0.9000, 0.9315,  ..., 0.7413, 0.7498, 0.7518],
#         [0.8807, 0.8803, 0.9089,  ..., 0.7398, 0.7522, 0.7535],
#         [0.8584, 0.8585, 0.8816,  ..., 0.7387, 0.7539, 0.7542],
#         ...,
#         [0.8303, 0.8263, 0.8017,  ..., 0.7366, 0.7354, 0.7356],
#         [0.8397, 0.8377, 0.8182,  ..., 0.7347, 0.7341, 0.7323],
#         [0.8489, 0.8497, 0.8364,  ..., 0.7329, 0.7333, 0.7292]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# y轴最终预测结果
# y轴预测形状torch.Size([1171, 450])
# ...
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# x轴最终预测结果
# x轴预测形状torch.Size([1531, 90])
# tensor([[0.8116, 0.8050, 0.8040,  ..., 0.7208, 0.7330, 0.7251],
#         [0.8092, 0.8025, 0.8014,  ..., 0.7202, 0.7325, 0.7244],
#         [0.8083, 0.8015, 0.8002,  ..., 0.7198, 0.7321, 0.7238],
#         ...,
#         [0.7971, 0.7832, 0.7742,  ..., 0.7685, 0.7790, 0.7705],
#         [0.7924, 0.7781, 0.7699,  ..., 0.7698, 0.7795, 0.7714],
#         [0.7850, 0.7710, 0.7645,  ..., 0.7708, 0.7799, 0.7715]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24160\880397507.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_24160\880397507.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# y轴最终预测结果
# y轴预测形状torch.Size([1531, 90])
# tensor([[0.4200, 0.4173, 0.4240,  ..., 0.3727, 0.3761, 0.3708],
#         [0.4217, 0.4194, 0.4257,  ..., 0.3717, 0.3754, 0.3701],
#         [0.4239, 0.4218, 0.4278,  ..., 0.3707, 0.3747, 0.3693],
#         ...,
#         [0.4618, 0.4811, 0.4920,  ..., 0.3543, 0.3595, 0.3565],
#         [0.4522, 0.4718, 0.4832,  ..., 0.3517, 0.3558, 0.3540],
#         [0.4495, 0.4689, 0.4797,  ..., 0.3493, 0.3533, 0.3524]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# z轴最终预测结果
# z轴预测形状torch.Size([1531, 90])
# tensor([[0.3811, 0.3874, 0.3905,  ..., 0.4749, 0.4734, 0.4715],
#         [0.3767, 0.3869, 0.3930,  ..., 0.4757, 0.4741, 0.4722],
#         [0.3735, 0.3857, 0.3938,  ..., 0.4761, 0.4745, 0.4727],
#         ...,
#         [0.3926, 0.3954, 0.3988,  ..., 0.4758, 0.4720, 0.4728],
#         [0.3909, 0.3937, 0.3979,  ..., 0.4762, 0.4723, 0.4736],
#         [0.3931, 0.3954, 0.3992,  ..., 0.4765, 0.4724, 0.4742]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小137790
# 9_MattSwift_fixations_sample_model_1s平均误差0.2683568912843175
# 现在对2s进行预测
# x轴真实情况torch.Size([1441, 180])
# y轴真实情况torch.Size([1441, 180])
# z轴真实情况torch.Size([1441, 180])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# x轴最终预测结果
# x轴预测形状torch.Size([1441, 180])
# tensor([[0.8375, 0.8377, 0.8392,  ..., 0.8072, 0.8006, 0.8014],
#         [0.8360, 0.8360, 0.8382,  ..., 0.8070, 0.8001, 0.8011],
#         [0.8351, 0.8347, 0.8375,  ..., 0.8066, 0.7995, 0.8007],
#         ...,
#         [0.9314, 0.8977, 0.8811,  ..., 0.7699, 0.7787, 0.7776],
#         [0.9615, 0.9312, 0.9181,  ..., 0.7657, 0.7745, 0.7746],
#         [0.9535, 0.9368, 0.9304,  ..., 0.7673, 0.7765, 0.7767]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# y轴最终预测结果
# y轴预测形状torch.Size([1441, 180])
# tensor([[ 0.4068,  0.4072,  0.4088,  ...,  0.3879,  0.3900,  0.3863],
#         [ 0.4115,  0.4118,  0.4130,  ...,  0.3889,  0.3907,  0.3870],
#         [ 0.4154,  0.4152,  0.4159,  ...,  0.3900,  0.3915,  0.3876],
#         ...,
#         [-0.0645, -0.0943, -0.0747,  ...,  0.3554,  0.3541,  0.3524],
#         [-0.0341, -0.0466, -0.0263,  ...,  0.3657,  0.3600,  0.3627],
#         [ 0.0354,  0.0283,  0.0403,  ...,  0.3725,  0.3640,  0.3699]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# z轴最终预测结果
# z轴预测形状torch.Size([1441, 180])
# tensor([[0.4049, 0.4121, 0.4060,  ..., 0.4579, 0.4631, 0.4621],
#         [0.4041, 0.4104, 0.4033,  ..., 0.4581, 0.4634, 0.4625],
#         [0.4031, 0.4084, 0.4006,  ..., 0.4585, 0.4638, 0.4630],
#         ...,
#         [0.5029, 0.5152, 0.5221,  ..., 0.4538, 0.4565, 0.4559],
#         [0.5158, 0.5263, 0.5301,  ..., 0.4557, 0.4582, 0.4568],
#         [0.5321, 0.5407, 0.5390,  ..., 0.4576, 0.4601, 0.4581]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小259380
# 9_MattSwift_fixations_sample_model_2s平均误差0.4093950018190496
# 现在对3s进行预测
# x轴真实情况torch.Size([1351, 270])
# y轴真实情况torch.Size([1351, 270])
# z轴真实情况torch.Size([1351, 270])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# x轴最终预测结果
# x轴预测形状torch.Size([1351, 270])
# tensor([[0.8005, 0.7993, 0.7949,  ..., 0.7809, 0.7832, 0.7850],
#         [0.7984, 0.7974, 0.7932,  ..., 0.7808, 0.7831, 0.7851],
#         [0.7970, 0.7960, 0.7918,  ..., 0.7808, 0.7829, 0.7851],
#         ...,
#         [0.9252, 0.8988, 0.8670,  ..., 0.7808, 0.7834, 0.7813],
#         [0.8886, 0.8647, 0.8413,  ..., 0.7796, 0.7799, 0.7791],
#         [0.8423, 0.8250, 0.8143,  ..., 0.7776, 0.7770, 0.7771]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# y轴最终预测结果
# y轴预测形状torch.Size([1351, 270])
# tensor([[0.4374, 0.4380, 0.4336,  ..., 0.3718, 0.3718, 0.3732],
#         [0.4396, 0.4404, 0.4357,  ..., 0.3726, 0.3726, 0.3742],
#         [0.4415, 0.4421, 0.4369,  ..., 0.3737, 0.3737, 0.3752],
#         ...,
#         [0.1086, 0.1530, 0.2286,  ..., 0.3715, 0.3629, 0.3568],
#         [0.1041, 0.1582, 0.2311,  ..., 0.3718, 0.3620, 0.3599],
#         [0.1213, 0.1772, 0.2426,  ..., 0.3695, 0.3617, 0.3642]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# z轴最终预测结果
# z轴预测形状torch.Size([1351, 270])
# tensor([[0.3646, 0.3627, 0.3667,  ..., 0.4546, 0.4557, 0.4655],
#         [0.3655, 0.3624, 0.3648,  ..., 0.4548, 0.4560, 0.4657],
#         [0.3675, 0.3631, 0.3639,  ..., 0.4550, 0.4562, 0.4658],
#         ...,
#         [0.5328, 0.5299, 0.5271,  ..., 0.4529, 0.4497, 0.4543],
#         [0.5172, 0.5138, 0.5092,  ..., 0.4543, 0.4497, 0.4544],
#         [0.5030, 0.4986, 0.4918,  ..., 0.4556, 0.4498, 0.4545]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小364770
# 9_MattSwift_fixations_sample_model_3s平均误差0.5598428819291379
# 现在对4s进行预测
# x轴真实情况torch.Size([1261, 360])
# y轴真实情况torch.Size([1261, 360])
# z轴真实情况torch.Size([1261, 360])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# x轴最终预测结果
# x轴预测形状torch.Size([1261, 360])
# tensor([[0.8323, 0.8398, 0.8427,  ..., 0.7798, 0.7819, 0.7827],
#         [0.8294, 0.8370, 0.8394,  ..., 0.7798, 0.7819, 0.7830],
#         [0.8267, 0.8344, 0.8363,  ..., 0.7797, 0.7820, 0.7834],
#         ...,
#         [0.8050, 0.8132, 0.8176,  ..., 0.7685, 0.7641, 0.7675],
#         [0.7977, 0.8089, 0.8197,  ..., 0.7664, 0.7626, 0.7666],
#         [0.7961, 0.8096, 0.8250,  ..., 0.7651, 0.7618, 0.7661]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# y轴最终预测结果
# y轴预测形状torch.Size([1261, 360])
# tensor([[0.4209, 0.4333, 0.4363,  ..., 0.3921, 0.3975, 0.3988],
#         [0.4202, 0.4329, 0.4358,  ..., 0.3921, 0.3971, 0.3983],
#         [0.4199, 0.4326, 0.4355,  ..., 0.3915, 0.3964, 0.3974],
#         ...,
#         [0.3548, 0.3819, 0.4152,  ..., 0.4033, 0.4053, 0.4103],
#         [0.3773, 0.4020, 0.4319,  ..., 0.4017, 0.4072, 0.4070],
#         [0.4085, 0.4307, 0.4578,  ..., 0.4004, 0.4078, 0.4055]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# z轴最终预测结果
# z轴预测形状torch.Size([1261, 360])
# tensor([[0.3794, 0.3781, 0.3723,  ..., 0.4523, 0.4538, 0.4570],
#         [0.3800, 0.3773, 0.3700,  ..., 0.4520, 0.4537, 0.4570],
#         [0.3816, 0.3777, 0.3690,  ..., 0.4517, 0.4537, 0.4569],
#         ...,
#         [0.4596, 0.4646, 0.4524,  ..., 0.4665, 0.4703, 0.4670],
#         [0.4602, 0.4647, 0.4525,  ..., 0.4672, 0.4709, 0.4675],
#         [0.4579, 0.4609, 0.4478,  ..., 0.4677, 0.4714, 0.4680]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小453960
# 9_MattSwift_fixations_sample_model_4s平均误差0.7223232546719951
# 现在对5s进行预测
# x轴真实情况torch.Size([1171, 450])
# y轴真实情况torch.Size([1171, 450])
# z轴真实情况torch.Size([1171, 450])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# x轴最终预测结果
# x轴预测形状torch.Size([1171, 450])
# tensor([[0.8366, 0.8396, 0.8370,  ..., 0.7665, 0.7640, 0.7682],
#         [0.8341, 0.8369, 0.8344,  ..., 0.7661, 0.7637, 0.7678],
#         [0.8317, 0.8343, 0.8318,  ..., 0.7657, 0.7635, 0.7674],
#         ...,
#         [0.5914, 0.5974, 0.6084,  ..., 0.8064, 0.8069, 0.8094],
#         [0.5704, 0.5915, 0.6162,  ..., 0.8068, 0.8088, 0.8107],
#         [0.5568, 0.5933, 0.6323,  ..., 0.8073, 0.8104, 0.8118]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# y轴最终预测结果
# y轴预测形状torch.Size([1171, 450])
# tensor([[0.4266, 0.4256, 0.4286,  ..., 0.3924, 0.3877, 0.3923],
#         [0.4291, 0.4283, 0.4314,  ..., 0.3917, 0.3871, 0.3920],
#         [0.4316, 0.4310, 0.4340,  ..., 0.3909, 0.3865, 0.3918],
#         ...,
#         [0.6727, 0.6241, 0.5492,  ..., 0.3775, 0.3872, 0.4043],
#         [0.6264, 0.5560, 0.4721,  ..., 0.3875, 0.3963, 0.4192],
#         [0.5893, 0.4987, 0.4046,  ..., 0.3973, 0.4041, 0.4272]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# z轴最终预测结果
# z轴预测形状torch.Size([1171, 450])
# tensor([[0.3800, 0.3839, 0.3916,  ..., 0.4698, 0.4643, 0.4691],
#         [0.3810, 0.3835, 0.3902,  ..., 0.4696, 0.4639, 0.4689],
#         [0.3826, 0.3835, 0.3890,  ..., 0.4695, 0.4636, 0.4686],
#         ...,
#         [0.4809, 0.4865, 0.4944,  ..., 0.4658, 0.4587, 0.4662],
#         [0.4943, 0.4999, 0.5086,  ..., 0.4656, 0.4589, 0.4662],
#         [0.5085, 0.5142, 0.5242,  ..., 0.4655, 0.4594, 0.4663]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小526950
# 9_MattSwift_fixations_sample_model_5s平均误差0.8686503660464215
