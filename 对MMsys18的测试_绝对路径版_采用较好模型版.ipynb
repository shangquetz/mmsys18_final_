# %%
import matplotlib.pyplot as plt
from PyEMD import EMD  # 补充导入EMD类
import numpy as np
import os
from pathlib import Path
from PyEMD import EMD
import torch
import torch.nn as nn
import torch.optim as optim



# 定义设备：如果有显卡就用 cuda，否则回退到 cpu
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"当前运行设备: {device}")




list_average_od_pred_1s=[]
list_average_od_pred_2s=[]
list_average_od_pred_3s=[]
list_average_od_pred_4s=[]
list_average_od_pred_5s=[]
#os.chdir('...')
a=Path("D:\MMsys18_final\sampled_data")
for b in a.iterdir():
    globals()[f"{b.stem}_pred"]=[]
    print(f'现在对{b.stem}进行预测')
    if b.suffix in ('.csv', '.txt'):
        data = np.genfromtxt(b, delimiter=',', skip_header=1)
        # 读取文件
        # os.chdir("D:\H\sampled_data")
        # data = np.genfromtxt("2_Diner_fixations_sample.csv", delimiter=',')

        od_values_list = []
        list_average_od = []

        # 对xyz三轴划分测试集
        x = data[:, 0]
        split_point = int(len(x) * 0.7)
        test_data_x = x[split_point:]
        print(f'测试集x轴长度{test_data_x.shape}')

        y = data[:, 1]
        split_point = int(len(y) * 0.7)
        test_data_y = y[split_point:]
        print(f'测试集y轴长度{test_data_y.shape}')

        z = data[:, 2]
        split_point = int(len(z) * 0.7)
        test_data_z = z[split_point:]
        print(f'测试集z轴长度{test_data_z.shape}')

        # 初始化EMD对象
        emd = EMD(max_imfs=7)
        # 执行EMD分解
        imfs_x = emd(x)  # 假设signal是已经定义好的输入信号
        imfs_x = imfs_x[:, split_point:]
        # imfs_x_label=x[-450:]
        # imfs_x_label=imfs_x_label[None,...]
        # imfs_x_label=torch.from_numpy(imfs_x_label)
        print(f'imfs_x的形状{imfs_x.shape}')
        # print(f'label的形状{imfs_x_label.shape}')

        # list_x_label=[]

        imfs_y = emd(y)
        imfs_y = imfs_y[:, split_point:]
        # imfs_y_label=y[-450:]
        # imfs_y_label=imfs_y_label[None,...]
        # imfs_y_label=torch.from_numpy(imfs_y_label)
        print(f'imfs_y的形状{imfs_y.shape}')
        # print(f'label的形状{imfs_y_label.shape}')

        # list_y_label=[]

        imfs_z = emd(z)
        imfs_z = imfs_z[:, split_point:]
        # imfs_z_label=z[-450:]
        # imfs_z_label=imfs_z_label[None,...]
        # imfs_z_label=torch.from_numpy(imfs_z_label)
        print(f'imfs_z的形状{imfs_z.shape}')
        # print(f'label的形状{imfs_z_label.shape}')

        # list_z_label=[]
        model_folder_name=b.name[:-4]+'_model'

        os.chdir(fr"D:\MMsys18_final\save_model_better\{model_folder_name}")
        for index in range(5):
            print(f'现在对{index + 1}s进行预测')

            os.chdir(fr"D:\MMsys18_final\save_model_better\{model_folder_name}\model_save_{index + 1}s")
            # 真实值采用滑动窗口对齐数据规模
            window_size_label = (index + 1) * 90


            def windows_label(a):
                samples = []
                for i in range(90, len(a) - window_size_label + 1):
                    samples.append(a[i:i + window_size_label])
                data_2d = np.array(samples)
                return data_2d


            # 真实值转换为tensor
            def transform_label(IMF):
                data_2d = windows_label(IMF)
                tensor = torch.from_numpy(data_2d)
                tensor_32_y_pred = tensor.float()
                return tensor_32_y_pred


            # 输入值滑动窗口

            window_size = 90


            def windows(a):
                window_size = 90
                samples = []
                for i in range(len(a) - window_size - window_size_label + 1):
                    samples.append(a[i:i + window_size])
                data_2d = np.array(samples)
                return data_2d


            # IMF转换为符合LSTM输入的三阶张量
            def transform(IMF):
                data_2d = windows(IMF)
                data_3d = data_2d[..., None]
                tensor = torch.from_numpy(data_3d)
                tensor_32 = tensor.float()
                return tensor_32


            tensor_32_label_x = transform_label(test_data_x)
            tensor_32_label_x = tensor_32_label_x.to(device)
            print(f'x轴真实情况{tensor_32_label_x.shape}')

            tensor_32_label_y = transform_label(test_data_y)
            tensor_32_label_y = tensor_32_label_y.to(device)
            print(f'y轴真实情况{tensor_32_label_y.shape}')

            tensor_32_label_z = transform_label(test_data_z)
            tensor_32_label_z = tensor_32_label_z.to(device)
            print(f'z轴真实情况{tensor_32_label_z.shape}')


            class ViewportPredictor(nn.Module):
                def __init__(self, input_dim, hidden_dim, horizon_H):
                    super(ViewportPredictor, self).__init__()

                    # --- 1. 双层堆叠 LSTM 部分 ---
                    self.lstm1 = nn.LSTM(input_dim, hidden_dim, batch_first=True)
                    self.lstm2 = nn.LSTM(hidden_dim, hidden_dim, batch_first=True)

                    # --- 2. 预测融合模块 (三层 MLP) ---
                    # 输入是 h' 和 c' 的拼接，维度为 hidden_dim * 2
                    self.tanh = nn.Tanh()
                    self.relu = nn.ReLU()

                    # 公式 (11) & (12) 的三层 MLP 结构
                    self.full_a = nn.Linear(hidden_dim * 2, 128)  # 升维
                    self.full_b = nn.Linear(128, 256)  # 中间层
                    self.full_c = nn.Linear(256, (index + 1) * 90)  # 映射到未来 H 时间段

                def forward(self, x):
                    # --- LSTM 层处理 (公式 8, 9) ---
                    output1, _ = self.lstm1(x)  # 第一层输出全序列 h
                    output2, (hn2, cn2) = self.lstm2(output1)  # 第二层接收 h，排除第一层的 c

                    # --- 特征提取 (公式 10) ---
                    h_last = hn2.squeeze(0)
                    c_last = cn2.squeeze(0)
                    combined = torch.cat((h_last, c_last), dim=1)  # h' ⊕ C'
                    pm_i_h = self.tanh(combined)  # 初始融合特征

                    # --- 三层 MLP 预测 (公式 11, 12) ---
                    # 第一层: ReLU(Full_a)dioaca
                    x_mlp = self.relu(self.full_a(pm_i_h))
                    # 第二层: ReLU(Full_b)
                    x_mlp = self.relu(self.full_b(x_mlp))
                    # 第三层: Linear(Full_c) -> 得到未来 H 的轨迹
                    prediction_h = self.full_c(x_mlp)

                    return prediction_h


            # 创建空列表
            list_x = []
            list_y = []
            list_z = []

            # 预测x轴
            print('开始预测x轴')


            def transform_1d_3d(IMF):
                data_2d = IMF[None, ...]
                data_3d = data_2d[..., None]
                tensor = torch.from_numpy(data_3d)
                tensor_32 = tensor.float()
                return tensor_32


            for i in range(len(imfs_x)):
                # 1. 直接加载整个模型文件
                model = torch.load(f'complete_model_x_pred_{index + 1}s_{i + 1}',weights_only=False)
                # 2. 切换到评估模式（依然非常重要！）
                model.eval()
                model.to(device)

                IMF_x = imfs_x[i, :]
                # print(IMF_x.shape)
                tensor_32 = transform(IMF_x)
                tensor_32 = tensor_32.to(device)
                # print(tensor_32.shape)
                # tensor_32_label=transform_label(IMF_x)
                # tensor_32_label=tensor_32_label.to(device)
                # list_x_label.append(tensor_32_label)

                outputs = model(tensor_32)

                print(f'此时预测imf{i + 1}输出形状{outputs.shape}')
                # print(f'采用的模型complete_model_x{i+1}___{model}')
                # print(outputs.shape)
                # print(outputs)

                list_x.append(outputs)
            # list_x_label=torch.cat(list_x_label,dim=0)
            list_2d_x = torch.sum(torch.stack(list_x), dim=0)
            print('x轴最终预测结果')
            print(f'x轴预测形状{list_2d_x.shape}')
            # print(f'x轴真实情况{list_x_label.shape}')
            print(list_2d_x)

            # 预测y轴
            print('-------------------------------')
            print('开始预测y轴')
            for i in range(len(imfs_y)):
                # 1. 直接加载整个模型文件
                model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
                # 2. 切换到评估模式（依然非常重要！）
                model.eval()
                model.to(device)

                IMF_y = imfs_y[i, :]
                tensor_32 = transform(IMF_y)
                tensor_32 = tensor_32.to(device)
                # tensor_32_label=transform_label(IMF_y)
                # tensor_32_label=tensor_32_label.to(device)

                outputs = model(tensor_32)

                print(f'此时预测imf{i + 1}输出形状{outputs.shape}')
                # print(f'采用的模型complete_model_y{i+1}___{model}')
                # print(outputs.shape)
                # print(outputs)

                list_y.append(outputs)
            list_2d_y = torch.sum(torch.stack(list_y), dim=0)
            print('y轴最终预测结果')
            print(f'y轴预测形状{list_2d_y.shape}')
            print(list_2d_y)

            print('-------------------------------------')
            print('开始预测z轴')
            for i in range(len(imfs_z)):
                # 1. 直接加载整个模型文件
                model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
                # 2. 切换到评估模式（依然非常重要！）
                model.eval()
                model.to(device)

                IMF_z = imfs_z[i, :]
                tensor_32 = transform(IMF_z)
                tensor_32 = tensor_32.to(device)
                # tensor_32_label=transform_label(IMF_z)
                # tensor_32_label=tensor_32_label.to(device)

                outputs = model(tensor_32)

                print(f'此时预测imf{i + 1}输出形状{outputs.shape}')
                # print(f'采用的模型complete_model_z{i+1}___{model}')
                # print(outputs.shape)
                # print(outputs)

                list_z.append(outputs)
            list_2d_z = torch.sum(torch.stack(list_z), dim=0)
            print('z轴最终预测结果')
            print(f'z轴预测形状{list_2d_z.shape}')
            print(list_2d_z)

            # 真实值和预测值组成列表
            # list_label=torch.cat([imfs_x_label,imfs_y_label,imfs_z_label],dim=0)
            # list_label=list_label.to(device)
            # print(f'真实标签形状{list_label.shape}')
            # print(f'真实标签数据{list_label}')
            # list_pred=torch.cat([list_2d_x,list_2d_y,list_2d_z],dim=0)
            # list_pred=list_pred.to(device)
            # print(f'预测形状{list_pred.shape}')
            # print(f'预测数据{list_pred}')

            # 评估（采用OD来写）
            for row in range(len(test_data_x) - window_size - window_size_label + 1):
                for i in range(window_size_label):
                    # 2. 从拼接后的张量中切片取出对应的分量
                    x1, y1, z1 = tensor_32_label_x[row, i], tensor_32_label_y[row, i], tensor_32_label_z[row, i]
                    x2, y2, z2 = list_2d_x[row, i], list_2d_y[row, i], list_2d_z[row, i]
                    # 3. 按照公式计算点积 (Dot Product)
                    # Formula: x1*x2 + y1*y2 + z1*z2

                    dot_product = x1 * x2 + y1 * y2 + z1 * z2

                    # 4. 数值安全处理：acos 的输入必须在 [-1, 1] 之间，否则会产生 NaN
                    dot_product = torch.clamp(dot_product, -1.0, 1.0)
                    # 5. 计算最终的 OD (即 arccos)
                    od_values = torch.acos(dot_product)
                    od_values_list.append(od_values.item())
            average_od = sum(od_values_list) / (
                        (len(test_data_x) - window_size - window_size_label + 1) * window_size_label)
            print(f'数据集大小{((len(test_data_x) - window_size - window_size_label + 1) * window_size_label)}')
            # print(f'计算得到的 OD 序列形状: {od_values_list.shape}') # 形状应该是 (N,)
            # print(f'最终得到的OD序列{od_values_list.shape}')
            print(f'{model_folder_name}_{index + 1}s平均误差{average_od}')

            globals()[f"{b.stem}_pred"].append(average_od)


            if index==0:
                list_average_od_pred_1s.append(average_od)
            elif index==1:
                list_average_od_pred_2s.append(average_od)
            elif index==2:
                list_average_od_pred_3s.append(average_od)
            elif index==3:
                list_average_od_pred_4s.append(average_od)
            elif index==4:
                list_average_od_pred_5s.append(average_od)



        plt.figure(figsize=(10, 5))
        plt.plot(globals()[f"{b.stem}_pred"], label='average_od', color='red', linewidth=2)
        plt.title(f'Visualization_average_od_{b.stem}')
        plt.xlabel('second')
        plt.xticks(ticks=range(len(globals()[f"{b.stem}_pred"])), labels=range(1, len(globals()[f"{b.stem}_pred"])+1))
        plt.ylabel('average_od')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.savefig(fr"D:\MMsys18_final\save_figure_better\{b.stem}_figure.png")
        plt.show()


average_pred_1s=sum(list_average_od_pred_1s)/len(list_average_od_pred_1s)
average_pred_2s=sum(list_average_od_pred_2s)/len(list_average_od_pred_2s)
average_pred_3s=sum(list_average_od_pred_3s)/len(list_average_od_pred_3s)
average_pred_4s=sum(list_average_od_pred_4s)/len(list_average_od_pred_4s)
average_pred_5s=sum(list_average_od_pred_5s)/len(list_average_od_pred_5s)
average_pred_1s_5s=[average_pred_1s,average_pred_2s,average_pred_3s,average_pred_4s,average_pred_5s]

plt.figure(figsize=(10, 5))
plt.plot(average_pred_1s_5s, label='average_od', color='red', linewidth=2)
plt.title('Visualization_average_od_sum')
plt.xlabel('second')
plt.xticks(ticks=range(len(average_pred_1s_5s)),labels=range(1,len(average_pred_1s_5s)+1))
plt.ylabel('average_od')
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig(fr"D:\MMsys18_final\save_figure_better\sum_figure.png")
plt.show()
# 假设你的 od_values_list 已经计算完成

# plt.figure(figsize=(10, 5))
# plt.plot(od_values_list, label='Orientation Distance (OD)', color='blue', linewidth=1)
# plt.axhline(y=0, color='r', linestyle='--', label='Perfect Alignment (OD=0)')  # 参考线

# plt.title('Visualization of OD Values')
# plt.xlabel('Sample Index')
# plt.ylabel('Angle (Radians)')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.show()
# Out:
# 当前运行设备: cuda
# 现在对10_Cows_fixations_sample进行预测
# 测试集x轴长度(1710,)
# 测试集y轴长度(1710,)
# 测试集z轴长度(1710,)
# imfs_x的形状(11, 1710)
# imfs_y的形状(10, 1710)
# imfs_z的形状(10, 1710)
# 现在对1s进行预测
# x轴真实情况torch.Size([1531, 90])
# y轴真实情况torch.Size([1531, 90])
# z轴真实情况torch.Size([1531, 90])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# x轴最终预测结果
# x轴预测形状torch.Size([1531, 90])
# tensor([[0.8567, 0.8495, 0.7892,  ..., 0.8163, 0.8833, 0.8351],
#         [0.8565, 0.8494, 0.7891,  ..., 0.8163, 0.8833, 0.8352],
#         [0.8564, 0.8493, 0.7891,  ..., 0.8162, 0.8833, 0.8352],
#         ...,
#         [0.8564, 0.8490, 0.7889,  ..., 0.8158, 0.8831, 0.8349],
#         [0.8560, 0.8489, 0.7890,  ..., 0.8158, 0.8832, 0.8349],
#         [0.8556, 0.8488, 0.7891,  ..., 0.8159, 0.8833, 0.8349]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# y轴最终预测结果
# y轴预测形状torch.Size([1531, 90])
# tensor([[0.4690, 0.4587, 0.4499,  ..., 0.4735, 0.3709, 0.4503],
#         [0.4689, 0.4588, 0.4498,  ..., 0.4735, 0.3709, 0.4503],
#         [0.4689, 0.4588, 0.4498,  ..., 0.4735, 0.3708, 0.4503],
#         ...,
#         [0.4717, 0.4615, 0.4500,  ..., 0.4729, 0.3708, 0.4517],
#         [0.4720, 0.4619, 0.4498,  ..., 0.4733, 0.3708, 0.4521],
#         [0.4718, 0.4623, 0.4496,  ..., 0.4737, 0.3709, 0.4521]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# z轴最终预测结果
# z轴预测形状torch.Size([1531, 90])
# tensor([[0.4973, 0.5001, 0.4916,  ..., 0.4597, 0.4759, 0.4826],
#         [0.4973, 0.5002, 0.4916,  ..., 0.4597, 0.4759, 0.4826],
#         [0.4973, 0.5003, 0.4917,  ..., 0.4598, 0.4758, 0.4825],
#         ...,
#         [0.4965, 0.4985, 0.4912,  ..., 0.4588, 0.4755, 0.4830],
#         [0.4965, 0.4984, 0.4912,  ..., 0.4588, 0.4755, 0.4830],
#         [0.4965, 0.4984, 0.4912,  ..., 0.4588, 0.4755, 0.4829]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31804\913658689.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31804\913658689.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
# 数据集大小137790
# 10_Cows_fixations_sample_model_1s平均误差0.09258617880956588
# 现在对2s进行预测
# x轴真实情况torch.Size([1441, 180])
# y轴真实情况torch.Size([1441, 180])
# z轴真实情况torch.Size([1441, 180])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# x轴最终预测结果
# x轴预测形状torch.Size([1441, 180])
# tensor([[0.8426, 0.7506, 0.7812,  ..., 0.8403, 0.8220, 0.8096],
#         [0.8425, 0.7505, 0.7811,  ..., 0.8403, 0.8220, 0.8096],
#         [0.8424, 0.7504, 0.7810,  ..., 0.8403, 0.8220, 0.8096],
#         ...,
#         [0.8428, 0.7515, 0.7813,  ..., 0.8405, 0.8221, 0.8099],
#         [0.8429, 0.7513, 0.7813,  ..., 0.8407, 0.8221, 0.8098],
#         [0.8430, 0.7512, 0.7814,  ..., 0.8408, 0.8222, 0.8098]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# y轴最终预测结果
# y轴预测形状torch.Size([1441, 180])
# tensor([[0.4446, 0.4314, 0.4284,  ..., 0.4239, 0.4686, 0.4493],
#         [0.4447, 0.4316, 0.4286,  ..., 0.4239, 0.4686, 0.4493],
#         [0.4449, 0.4318, 0.4287,  ..., 0.4239, 0.4686, 0.4493],
#         ...,
#         [0.4458, 0.4306, 0.4264,  ..., 0.4217, 0.4668, 0.4488],
#         [0.4457, 0.4306, 0.4263,  ..., 0.4218, 0.4668, 0.4488],
#         [0.4456, 0.4305, 0.4263,  ..., 0.4218, 0.4669, 0.4488]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# z轴最终预测结果
# z轴预测形状torch.Size([1441, 180])
# tensor([[0.4003, 0.4774, 0.5097,  ..., 0.5025, 0.5082, 0.4899],
#         [0.4003, 0.4774, 0.5097,  ..., 0.5025, 0.5081, 0.4899],
#         [0.4003, 0.4774, 0.5097,  ..., 0.5025, 0.5081, 0.4899],
#         ...,
#         [0.4003, 0.4777, 0.5097,  ..., 0.5023, 0.5080, 0.4893],
#         [0.4003, 0.4777, 0.5097,  ..., 0.5023, 0.5080, 0.4893],
#         [0.4003, 0.4777, 0.5097,  ..., 0.5023, 0.5080, 0.4894]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小259380
# 10_Cows_fixations_sample_model_2s平均误差0.13005171790154213
# 现在对3s进行预测
# x轴真实情况torch.Size([1351, 270])
# y轴真实情况torch.Size([1351, 270])
# z轴真实情况torch.Size([1351, 270])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# x轴最终预测结果
# x轴预测形状torch.Size([1351, 270])
# tensor([[0.8227, 0.7468, 0.9383,  ..., 0.5529, 0.8309, 0.8590],
#         [0.8226, 0.7467, 0.9382,  ..., 0.5529, 0.8309, 0.8591],
#         [0.8225, 0.7466, 0.9381,  ..., 0.5529, 0.8309, 0.8591],
#         ...,
#         [0.8224, 0.7468, 0.9384,  ..., 0.5524, 0.8302, 0.8590],
#         [0.8224, 0.7468, 0.9386,  ..., 0.5524, 0.8301, 0.8591],
#         [0.8224, 0.7468, 0.9388,  ..., 0.5524, 0.8300, 0.8591]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# y轴最终预测结果
# y轴预测形状torch.Size([1351, 270])
# tensor([[0.4582, 0.4899, 0.4799,  ..., 0.4880, 0.4646, 0.4847],
#         [0.4581, 0.4899, 0.4799,  ..., 0.4880, 0.4646, 0.4847],
#         [0.4581, 0.4899, 0.4799,  ..., 0.4880, 0.4646, 0.4848],
#         ...,
#         [0.4578, 0.4897, 0.4781,  ..., 0.4866, 0.4671, 0.4857],
#         [0.4575, 0.4893, 0.4779,  ..., 0.4866, 0.4671, 0.4857],
#         [0.4574, 0.4890, 0.4777,  ..., 0.4867, 0.4670, 0.4856]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# z轴最终预测结果
# z轴预测形状torch.Size([1351, 270])
# tensor([[0.5037, 0.5161, 0.4829,  ..., 0.4701, 0.5079, 0.5003],
#         [0.5038, 0.5161, 0.4829,  ..., 0.4702, 0.5079, 0.5003],
#         [0.5038, 0.5161, 0.4830,  ..., 0.4702, 0.5080, 0.5003],
#         ...,
#         [0.5033, 0.5159, 0.4827,  ..., 0.4700, 0.5078, 0.5000],
#         [0.5033, 0.5159, 0.4827,  ..., 0.4700, 0.5078, 0.5000],
#         [0.5033, 0.5159, 0.4827,  ..., 0.4700, 0.5078, 0.5000]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小364770
# 10_Cows_fixations_sample_model_3s平均误差0.1408490282361696
# 现在对4s进行预测
# x轴真实情况torch.Size([1261, 360])
# y轴真实情况torch.Size([1261, 360])
# z轴真实情况torch.Size([1261, 360])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# x轴最终预测结果
# x轴预测形状torch.Size([1261, 360])
# tensor([[0.8123, 0.7233, 0.8368,  ..., 0.8585, 0.7439, 0.8083],
#         [0.8123, 0.7233, 0.8368,  ..., 0.8585, 0.7439, 0.8084],
#         [0.8122, 0.7232, 0.8367,  ..., 0.8585, 0.7439, 0.8084],
#         ...,
#         [0.8125, 0.7232, 0.8366,  ..., 0.8584, 0.7437, 0.8083],
#         [0.8125, 0.7232, 0.8366,  ..., 0.8584, 0.7437, 0.8083],
#         [0.8124, 0.7232, 0.8366,  ..., 0.8584, 0.7438, 0.8083]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# y轴最终预测结果
# y轴预测形状torch.Size([1261, 360])
# tensor([[0.5066, 0.4909, 0.5026,  ..., 0.4897, 0.4918, 0.5061],
#         [0.5066, 0.4910, 0.5027,  ..., 0.4897, 0.4918, 0.5061],
#         [0.5067, 0.4910, 0.5027,  ..., 0.4897, 0.4918, 0.5061],
#         ...,
#         [0.5067, 0.4897, 0.5026,  ..., 0.4895, 0.4919, 0.5052],
#         [0.5066, 0.4897, 0.5025,  ..., 0.4894, 0.4919, 0.5051],
#         [0.5064, 0.4898, 0.5025,  ..., 0.4893, 0.4918, 0.5051]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# z轴最终预测结果
# z轴预测形状torch.Size([1261, 360])
# tensor([[0.4862, 0.4961, 0.4897,  ..., 0.4809, 0.4850, 0.4676],
#         [0.4862, 0.4961, 0.4898,  ..., 0.4810, 0.4850, 0.4676],
#         [0.4863, 0.4962, 0.4898,  ..., 0.4810, 0.4850, 0.4677],
#         ...,
#         [0.4858, 0.4957, 0.4892,  ..., 0.4805, 0.4844, 0.4671],
#         [0.4858, 0.4957, 0.4892,  ..., 0.4805, 0.4844, 0.4671],
#         [0.4858, 0.4957, 0.4893,  ..., 0.4805, 0.4844, 0.4671]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小453960
# 10_Cows_fixations_sample_model_4s平均误差0.1789524179642152
# 现在对5s进行预测
# x轴真实情况torch.Size([1171, 450])
# y轴真实情况torch.Size([1171, 450])
# z轴真实情况torch.Size([1171, 450])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# x轴最终预测结果
# x轴预测形状torch.Size([1171, 450])
# tensor([[0.7846, 0.8461, 0.8981,  ..., 0.8477, 0.7776, 0.8828],
#         [0.7846, 0.8461, 0.8980,  ..., 0.8477, 0.7776, 0.8829],
#         [0.7846, 0.8460, 0.8979,  ..., 0.8477, 0.7776, 0.8829],
#         ...,
#         [0.7844, 0.8462, 0.8980,  ..., 0.8478, 0.7773, 0.8827],
#         [0.7845, 0.8462, 0.8980,  ..., 0.8479, 0.7773, 0.8827],
#         [0.7845, 0.8461, 0.8980,  ..., 0.8479, 0.7773, 0.8827]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# y轴最终预测结果
# y轴预测形状torch.Size([1171, 450])
# tensor([[0.4700, 0.4785, 0.4786,  ..., 0.5033, 0.4850, 0.4673],
#         [0.4700, 0.4785, 0.4787,  ..., 0.5033, 0.4850, 0.4673],
#         [0.4701, 0.4786, 0.4788,  ..., 0.5033, 0.4849, 0.4673],
#         ...,
#         [0.4696, 0.4780, 0.4784,  ..., 0.5029, 0.4847, 0.4676],
#         [0.4695, 0.4780, 0.4783,  ..., 0.5029, 0.4847, 0.4676],
#         [0.4695, 0.4779, 0.4783,  ..., 0.5029, 0.4847, 0.4676]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# z轴最终预测结果
# z轴预测形状torch.Size([1171, 450])
# tensor([[0.4968, 0.4696, 0.4747,  ..., 0.4656, 0.4758, 0.4713],
#         [0.4968, 0.4696, 0.4748,  ..., 0.4656, 0.4758, 0.4712],
#         [0.4968, 0.4696, 0.4748,  ..., 0.4655, 0.4757, 0.4712],
#         ...,
#         [0.4964, 0.4693, 0.4741,  ..., 0.4656, 0.4756, 0.4717],
#         [0.4964, 0.4693, 0.4742,  ..., 0.4656, 0.4755, 0.4717],
#         [0.4965, 0.4693, 0.4742,  ..., 0.4656, 0.4755, 0.4716]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小526950
# 10_Cows_fixations_sample_model_5s平均误差0.22595526779754072
# 现在对11_Abbottsford_fixations_sample进行预测
# 测试集x轴长度(1710,)
# 测试集y轴长度(1710,)
# 测试集z轴长度(1710,)
# imfs_x的形状(11, 1710)
# imfs_y的形状(12, 1710)
# imfs_z的形状(10, 1710)
# 现在对1s进行预测
# x轴真实情况torch.Size([1531, 90])
# y轴真实情况torch.Size([1531, 90])
# z轴真实情况torch.Size([1531, 90])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# x轴最终预测结果
# x轴预测形状torch.Size([1531, 90])
# tensor([[0.8078, 0.7538, 0.8306,  ..., 0.8091, 0.7837, 0.6975],
#         [0.8078, 0.7538, 0.8306,  ..., 0.8091, 0.7837, 0.6975],
#         [0.8078, 0.7538, 0.8306,  ..., 0.8091, 0.7837, 0.6974],
#         ...,
#         [0.8078, 0.7536, 0.8306,  ..., 0.8089, 0.7836, 0.6972],
#         [0.8078, 0.7536, 0.8307,  ..., 0.8089, 0.7836, 0.6972],
#         [0.8078, 0.7536, 0.8307,  ..., 0.8089, 0.7837, 0.6972]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31804\913658689.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31804\913658689.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# 此时预测imf12输出形状torch.Size([1531, 90])
# y轴最终预测结果
# y轴预测形状torch.Size([1531, 90])
# tensor([[0.3308, 0.3429, 0.3316,  ..., 0.3178, 0.3435, 0.3332],
#         [0.3308, 0.3430, 0.3316,  ..., 0.3178, 0.3435, 0.3332],
#         [0.3308, 0.3430, 0.3316,  ..., 0.3178, 0.3436, 0.3332],
#         ...,
#         [0.3312, 0.3430, 0.3318,  ..., 0.3177, 0.3444, 0.3325],
#         [0.3311, 0.3429, 0.3317,  ..., 0.3177, 0.3443, 0.3326],
#         [0.3310, 0.3428, 0.3315,  ..., 0.3177, 0.3442, 0.3327]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# z轴最终预测结果
# z轴预测形状torch.Size([1531, 90])
# tensor([[0.5880, 0.5814, 0.5639,  ..., 0.5485, 0.5619, 0.5846],
#         [0.5879, 0.5814, 0.5639,  ..., 0.5485, 0.5619, 0.5846],
#         [0.5879, 0.5814, 0.5639,  ..., 0.5485, 0.5619, 0.5847],
#         ...,
#         [0.5881, 0.5814, 0.5640,  ..., 0.5486, 0.5623, 0.5851],
#         [0.5881, 0.5814, 0.5640,  ..., 0.5486, 0.5624, 0.5851],
#         [0.5881, 0.5814, 0.5641,  ..., 0.5486, 0.5624, 0.5851]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小137790
# 11_Abbottsford_fixations_sample_model_1s平均误差0.08903905594090754
# 现在对2s进行预测
# x轴真实情况torch.Size([1441, 180])
# y轴真实情况torch.Size([1441, 180])
# z轴真实情况torch.Size([1441, 180])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# x轴最终预测结果
# x轴预测形状torch.Size([1441, 180])
# tensor([[0.8406, 0.9030, 0.8848,  ..., 0.8973, 0.9167, 0.9319],
#         [0.8406, 0.9030, 0.8848,  ..., 0.8973, 0.9167, 0.9319],
#         [0.8406, 0.9030, 0.8848,  ..., 0.8973, 0.9167, 0.9320],
#         ...,
#         [0.8407, 0.9035, 0.8847,  ..., 0.8970, 0.9166, 0.9321],
#         [0.8406, 0.9034, 0.8846,  ..., 0.8971, 0.9167, 0.9321],
#         [0.8405, 0.9034, 0.8846,  ..., 0.8971, 0.9168, 0.9322]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# 此时预测imf12输出形状torch.Size([1441, 180])
# y轴最终预测结果
# y轴预测形状torch.Size([1441, 180])
# tensor([[0.3884, 0.3757, 0.3913,  ..., 0.3847, 0.3991, 0.3910],
#         [0.3884, 0.3757, 0.3913,  ..., 0.3847, 0.3991, 0.3910],
#         [0.3884, 0.3758, 0.3913,  ..., 0.3847, 0.3991, 0.3909],
#         ...,
#         [0.3886, 0.3746, 0.3908,  ..., 0.3842, 0.3996, 0.3917],
#         [0.3889, 0.3748, 0.3910,  ..., 0.3842, 0.3999, 0.3918],
#         [0.3890, 0.3750, 0.3912,  ..., 0.3842, 0.4001, 0.3919]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# z轴最终预测结果
# z轴预测形状torch.Size([1441, 180])
# tensor([[0.6445, 0.5929, 0.6055,  ..., 0.6182, 0.5887, 0.5815],
#         [0.6445, 0.5929, 0.6055,  ..., 0.6182, 0.5886, 0.5814],
#         [0.6445, 0.5929, 0.6055,  ..., 0.6182, 0.5886, 0.5814],
#         ...,
#         [0.6450, 0.5931, 0.6057,  ..., 0.6185, 0.5893, 0.5818],
#         [0.6449, 0.5931, 0.6057,  ..., 0.6185, 0.5894, 0.5818],
#         [0.6449, 0.5930, 0.6057,  ..., 0.6185, 0.5894, 0.5818]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小259380
# 11_Abbottsford_fixations_sample_model_2s平均误差0.07790263618113498
# 现在对3s进行预测
# x轴真实情况torch.Size([1351, 270])
# y轴真实情况torch.Size([1351, 270])
# z轴真实情况torch.Size([1351, 270])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# x轴最终预测结果
# x轴预测形状torch.Size([1351, 270])
# tensor([[0.7705, 0.7641, 0.7916,  ..., 0.7711, 0.8029, 0.7837],
#         [0.7705, 0.7641, 0.7916,  ..., 0.7711, 0.8029, 0.7837],
#         [0.7706, 0.7641, 0.7916,  ..., 0.7711, 0.8028, 0.7837],
#         ...,
#         [0.7704, 0.7639, 0.7912,  ..., 0.7713, 0.8027, 0.7837],
#         [0.7704, 0.7639, 0.7912,  ..., 0.7714, 0.8027, 0.7838],
#         [0.7704, 0.7639, 0.7912,  ..., 0.7714, 0.8027, 0.7838]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# 此时预测imf12输出形状torch.Size([1351, 270])
# y轴最终预测结果
# y轴预测形状torch.Size([1351, 270])
# tensor([[0.3534, 0.3317, 0.3599,  ..., 0.3439, 0.3304, 0.3523],
#         [0.3534, 0.3318, 0.3599,  ..., 0.3439, 0.3304, 0.3523],
#         [0.3535, 0.3318, 0.3599,  ..., 0.3440, 0.3304, 0.3523],
#         ...,
#         [0.3498, 0.3318, 0.3600,  ..., 0.3432, 0.3303, 0.3528],
#         [0.3498, 0.3318, 0.3600,  ..., 0.3433, 0.3304, 0.3528],
#         [0.3499, 0.3317, 0.3599,  ..., 0.3433, 0.3304, 0.3528]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# z轴最终预测结果
# z轴预测形状torch.Size([1351, 270])
# tensor([[0.5491, 0.5356, 0.5348,  ..., 0.5251, 0.5617, 0.5667],
#         [0.5491, 0.5356, 0.5348,  ..., 0.5251, 0.5617, 0.5667],
#         [0.5491, 0.5356, 0.5349,  ..., 0.5251, 0.5617, 0.5667],
#         ...,
#         [0.5492, 0.5359, 0.5355,  ..., 0.5253, 0.5615, 0.5666],
#         [0.5492, 0.5360, 0.5355,  ..., 0.5253, 0.5615, 0.5666],
#         [0.5492, 0.5360, 0.5355,  ..., 0.5252, 0.5615, 0.5666]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小364770
# 11_Abbottsford_fixations_sample_model_3s平均误差0.21569391716123326
# 现在对4s进行预测
# x轴真实情况torch.Size([1261, 360])
# y轴真实情况torch.Size([1261, 360])
# z轴真实情况torch.Size([1261, 360])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# x轴最终预测结果
# x轴预测形状torch.Size([1261, 360])
# tensor([[0.7482, 0.8387, 0.7576,  ..., 0.8111, 0.8381, 0.7946],
#         [0.7483, 0.8387, 0.7576,  ..., 0.8111, 0.8381, 0.7946],
#         [0.7483, 0.8387, 0.7576,  ..., 0.8111, 0.8381, 0.7946],
#         ...,
#         [0.7483, 0.8383, 0.7577,  ..., 0.8112, 0.8384, 0.7944],
#         [0.7482, 0.8382, 0.7579,  ..., 0.8113, 0.8385, 0.7946],
#         [0.7481, 0.8382, 0.7581,  ..., 0.8114, 0.8385, 0.7948]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# 此时预测imf12输出形状torch.Size([1261, 360])
# y轴最终预测结果
# y轴预测形状torch.Size([1261, 360])
# tensor([[0.3268, 0.2780, 0.2996,  ..., 0.3118, 0.3294, 0.3240],
#         [0.3268, 0.2780, 0.2997,  ..., 0.3118, 0.3294, 0.3240],
#         [0.3268, 0.2780, 0.2997,  ..., 0.3118, 0.3294, 0.3240],
#         ...,
#         [0.3279, 0.2781, 0.2996,  ..., 0.3101, 0.3307, 0.3245],
#         [0.3277, 0.2780, 0.2993,  ..., 0.3101, 0.3306, 0.3246],
#         [0.3274, 0.2778, 0.2990,  ..., 0.3103, 0.3306, 0.3246]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# z轴最终预测结果
# z轴预测形状torch.Size([1261, 360])
# tensor([[0.6489, 0.6320, 0.5702,  ..., 0.6552, 0.6122, 0.6276],
#         [0.6489, 0.6320, 0.5702,  ..., 0.6552, 0.6122, 0.6276],
#         [0.6489, 0.6321, 0.5702,  ..., 0.6552, 0.6122, 0.6276],
#         ...,
#         [0.6494, 0.6322, 0.5707,  ..., 0.6554, 0.6126, 0.6283],
#         [0.6494, 0.6322, 0.5706,  ..., 0.6554, 0.6126, 0.6283],
#         [0.6494, 0.6322, 0.5706,  ..., 0.6554, 0.6126, 0.6283]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小453960
# 11_Abbottsford_fixations_sample_model_4s平均误差0.24445007530537524
# 现在对5s进行预测
# x轴真实情况torch.Size([1171, 450])
# y轴真实情况torch.Size([1171, 450])
# z轴真实情况torch.Size([1171, 450])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# x轴最终预测结果
# x轴预测形状torch.Size([1171, 450])
# tensor([[0.7873, 0.7937, 0.7489,  ..., 0.8002, 0.7886, 0.7574],
#         [0.7873, 0.7937, 0.7489,  ..., 0.8002, 0.7886, 0.7574],
#         [0.7873, 0.7937, 0.7489,  ..., 0.8002, 0.7886, 0.7574],
#         ...,
#         [0.7874, 0.7937, 0.7488,  ..., 0.7999, 0.7885, 0.7581],
#         [0.7874, 0.7936, 0.7488,  ..., 0.7999, 0.7885, 0.7581],
#         [0.7874, 0.7936, 0.7488,  ..., 0.7998, 0.7885, 0.7582]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# 此时预测imf12输出形状torch.Size([1171, 450])
# y轴最终预测结果
# y轴预测形状torch.Size([1171, 450])
# tensor([[0.3290, 0.3302, 0.3432,  ..., 0.3357, 0.3305, 0.3507],
#         [0.3290, 0.3302, 0.3432,  ..., 0.3356, 0.3305, 0.3507],
#         [0.3290, 0.3302, 0.3432,  ..., 0.3356, 0.3305, 0.3507],
#         ...,
#         [0.3292, 0.3304, 0.3438,  ..., 0.3355, 0.3302, 0.3509],
#         [0.3291, 0.3303, 0.3438,  ..., 0.3355, 0.3302, 0.3509],
#         [0.3291, 0.3303, 0.3438,  ..., 0.3355, 0.3302, 0.3510]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# z轴最终预测结果
# z轴预测形状torch.Size([1171, 450])
# tensor([[0.5907, 0.5975, 0.5680,  ..., 0.5926, 0.5569, 0.5970],
#         [0.5907, 0.5975, 0.5680,  ..., 0.5926, 0.5569, 0.5970],
#         [0.5907, 0.5975, 0.5680,  ..., 0.5926, 0.5569, 0.5970],
#         ...,
#         [0.5909, 0.5980, 0.5681,  ..., 0.5927, 0.5571, 0.5970],
#         [0.5910, 0.5980, 0.5681,  ..., 0.5927, 0.5571, 0.5970],
#         [0.5910, 0.5981, 0.5681,  ..., 0.5927, 0.5571, 0.5970]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小526950
# 11_Abbottsford_fixations_sample_model_5s平均误差0.34502838603614133
# 现在对12_TeatroRegioTorino_fixations_sample进行预测
# 测试集x轴长度(1710,)
# 测试集y轴长度(1710,)
# 测试集z轴长度(1710,)
# imfs_x的形状(11, 1710)
# imfs_y的形状(10, 1710)
# imfs_z的形状(10, 1710)
# 现在对1s进行预测
# x轴真实情况torch.Size([1531, 90])
# y轴真实情况torch.Size([1531, 90])
# z轴真实情况torch.Size([1531, 90])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# x轴最终预测结果
# x轴预测形状torch.Size([1531, 90])
# tensor([[0.8748, 0.7834, 0.8022,  ..., 0.7915, 0.7525, 0.8301],
#         [0.8748, 0.7833, 0.8023,  ..., 0.7915, 0.7526, 0.8301],
#         [0.8747, 0.7833, 0.8023,  ..., 0.7915, 0.7526, 0.8301],
#         ...,
#         [0.8748, 0.7830, 0.8030,  ..., 0.7918, 0.7524, 0.8294],
#         [0.8746, 0.7831, 0.8029,  ..., 0.7917, 0.7524, 0.8294],
#         [0.8744, 0.7831, 0.8030,  ..., 0.7916, 0.7525, 0.8294]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# y轴最终预测结果
# y轴预测形状torch.Size([1531, 90])
# tensor([[0.3868, 0.3663, 0.3776,  ..., 0.4103, 0.3751, 0.3810],
#         [0.3867, 0.3663, 0.3776,  ..., 0.4103, 0.3752, 0.3810],
#         [0.3862, 0.3661, 0.3776,  ..., 0.4101, 0.3752, 0.3810],
#         ...,
#         [0.3793, 0.3637, 0.3759,  ..., 0.4079, 0.3766, 0.3766],
#         [0.3818, 0.3649, 0.3773,  ..., 0.4085, 0.3761, 0.3775],
#         [0.3848, 0.3660, 0.3790,  ..., 0.4092, 0.3756, 0.3785]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# z轴最终预测结果
# z轴预测形状torch.Size([1531, 90])
# tensor([[0.4931, 0.5562, 0.5385,  ..., 0.5360, 0.5639, 0.5567],
#         [0.4932, 0.5562, 0.5386,  ..., 0.5361, 0.5639, 0.5567],
#         [0.4932, 0.5562, 0.5386,  ..., 0.5361, 0.5639, 0.5567],
#         ...,
#         [0.4935, 0.5562, 0.5386,  ..., 0.5361, 0.5641, 0.5569],
#         [0.4935, 0.5562, 0.5386,  ..., 0.5361, 0.5641, 0.5569],
#         [0.4935, 0.5562, 0.5386,  ..., 0.5361, 0.5641, 0.5568]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31804\913658689.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31804\913658689.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
# 数据集大小137790
# 12_TeatroRegioTorino_fixations_sample_model_1s平均误差0.07286228637857405
# 现在对2s进行预测
# x轴真实情况torch.Size([1441, 180])
# y轴真实情况torch.Size([1441, 180])
# z轴真实情况torch.Size([1441, 180])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# x轴最终预测结果
# x轴预测形状torch.Size([1441, 180])
# tensor([[0.7736, 0.7755, 0.7958,  ..., 0.8543, 0.7984, 0.8208],
#         [0.7736, 0.7754, 0.7959,  ..., 0.8544, 0.7985, 0.8207],
#         [0.7737, 0.7754, 0.7959,  ..., 0.8544, 0.7985, 0.8208],
#         ...,
#         [0.7743, 0.7760, 0.7945,  ..., 0.8533, 0.7979, 0.8217],
#         [0.7741, 0.7759, 0.7943,  ..., 0.8533, 0.7979, 0.8217],
#         [0.7738, 0.7758, 0.7942,  ..., 0.8533, 0.7978, 0.8217]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# y轴最终预测结果
# y轴预测形状torch.Size([1441, 180])
# tensor([[0.3854, 0.3917, 0.3731,  ..., 0.3998, 0.3999, 0.4096],
#         [0.3854, 0.3919, 0.3730,  ..., 0.3996, 0.3998, 0.4093],
#         [0.3855, 0.3919, 0.3729,  ..., 0.3995, 0.3999, 0.4092],
#         ...,
#         [0.3862, 0.3886, 0.3738,  ..., 0.4008, 0.3992, 0.4112],
#         [0.3864, 0.3889, 0.3739,  ..., 0.4008, 0.3991, 0.4111],
#         [0.3868, 0.3892, 0.3739,  ..., 0.4008, 0.3991, 0.4110]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# z轴最终预测结果
# z轴预测形状torch.Size([1441, 180])
# tensor([[0.5191, 0.5305, 0.5096,  ..., 0.5064, 0.5187, 0.5048],
#         [0.5191, 0.5305, 0.5096,  ..., 0.5065, 0.5187, 0.5048],
#         [0.5191, 0.5305, 0.5096,  ..., 0.5065, 0.5187, 0.5048],
#         ...,
#         [0.5190, 0.5306, 0.5098,  ..., 0.5064, 0.5188, 0.5048],
#         [0.5190, 0.5306, 0.5098,  ..., 0.5064, 0.5189, 0.5048],
#         [0.5189, 0.5306, 0.5098,  ..., 0.5064, 0.5189, 0.5048]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小259380
# 12_TeatroRegioTorino_fixations_sample_model_2s平均误差0.15466979736155934
# 现在对3s进行预测
# x轴真实情况torch.Size([1351, 270])
# y轴真实情况torch.Size([1351, 270])
# z轴真实情况torch.Size([1351, 270])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# x轴最终预测结果
# x轴预测形状torch.Size([1351, 270])
# tensor([[0.8532, 0.9686, 1.0269,  ..., 0.9535, 0.9716, 0.9268],
#         [0.8532, 0.9686, 1.0269,  ..., 0.9535, 0.9716, 0.9268],
#         [0.8532, 0.9686, 1.0270,  ..., 0.9535, 0.9716, 0.9268],
#         ...,
#         [0.8530, 0.9681, 1.0269,  ..., 0.9529, 0.9723, 0.9271],
#         [0.8531, 0.9681, 1.0269,  ..., 0.9529, 0.9723, 0.9271],
#         [0.8532, 0.9680, 1.0270,  ..., 0.9528, 0.9722, 0.9272]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# y轴最终预测结果
# y轴预测形状torch.Size([1351, 270])
# tensor([[0.4536, 0.4394, 0.4540,  ..., 0.4106, 0.4311, 0.4230],
#         [0.4534, 0.4392, 0.4541,  ..., 0.4106, 0.4309, 0.4231],
#         [0.4533, 0.4393, 0.4542,  ..., 0.4106, 0.4309, 0.4232],
#         ...,
#         [0.4538, 0.4484, 0.4587,  ..., 0.4085, 0.4359, 0.4235],
#         [0.4538, 0.4480, 0.4587,  ..., 0.4083, 0.4357, 0.4235],
#         [0.4538, 0.4475, 0.4588,  ..., 0.4081, 0.4355, 0.4235]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# z轴最终预测结果
# z轴预测形状torch.Size([1351, 270])
# tensor([[0.4887, 0.4628, 0.4424,  ..., 0.4805, 0.4806, 0.4745],
#         [0.4887, 0.4628, 0.4424,  ..., 0.4805, 0.4804, 0.4745],
#         [0.4886, 0.4628, 0.4424,  ..., 0.4805, 0.4803, 0.4745],
#         ...,
#         [0.4888, 0.4628, 0.4425,  ..., 0.4804, 0.4805, 0.4745],
#         [0.4888, 0.4628, 0.4425,  ..., 0.4804, 0.4806, 0.4745],
#         [0.4887, 0.4628, 0.4425,  ..., 0.4804, 0.4806, 0.4746]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小364770
# 12_TeatroRegioTorino_fixations_sample_model_3s平均误差0.17530568458383464
# 现在对4s进行预测
# x轴真实情况torch.Size([1261, 360])
# y轴真实情况torch.Size([1261, 360])
# z轴真实情况torch.Size([1261, 360])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# x轴最终预测结果
# x轴预测形状torch.Size([1261, 360])
# tensor([[0.7426, 0.7833, 0.8515,  ..., 0.8527, 0.7815, 0.8608],
#         [0.7426, 0.7833, 0.8515,  ..., 0.8527, 0.7815, 0.8608],
#         [0.7426, 0.7833, 0.8515,  ..., 0.8527, 0.7815, 0.8608],
#         ...,
#         [0.7425, 0.7840, 0.8514,  ..., 0.8530, 0.7813, 0.8607],
#         [0.7425, 0.7840, 0.8514,  ..., 0.8530, 0.7813, 0.8607],
#         [0.7425, 0.7840, 0.8514,  ..., 0.8530, 0.7812, 0.8607]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# y轴最终预测结果
# y轴预测形状torch.Size([1261, 360])
# tensor([[0.3626, 0.3986, 0.4042,  ..., 0.3626, 0.4122, 0.3947],
#         [0.3624, 0.3987, 0.4041,  ..., 0.3628, 0.4123, 0.3946],
#         [0.3623, 0.3986, 0.4041,  ..., 0.3629, 0.4121, 0.3947],
#         ...,
#         [0.3619, 0.3980, 0.4070,  ..., 0.3615, 0.4120, 0.3945],
#         [0.3619, 0.3981, 0.4070,  ..., 0.3615, 0.4120, 0.3945],
#         [0.3619, 0.3981, 0.4070,  ..., 0.3615, 0.4120, 0.3945]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# z轴最终预测结果
# z轴预测形状torch.Size([1261, 360])
# tensor([[0.5089, 0.5270, 0.5193,  ..., 0.5207, 0.5157, 0.4979],
#         [0.5089, 0.5270, 0.5193,  ..., 0.5207, 0.5157, 0.4980],
#         [0.5089, 0.5270, 0.5193,  ..., 0.5207, 0.5157, 0.4980],
#         ...,
#         [0.5089, 0.5270, 0.5195,  ..., 0.5208, 0.5158, 0.4981],
#         [0.5089, 0.5270, 0.5195,  ..., 0.5208, 0.5158, 0.4981],
#         [0.5089, 0.5270, 0.5195,  ..., 0.5207, 0.5158, 0.4981]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小453960
# 12_TeatroRegioTorino_fixations_sample_model_4s平均误差0.24383413295512094
# 现在对5s进行预测
# x轴真实情况torch.Size([1171, 450])
# y轴真实情况torch.Size([1171, 450])
# z轴真实情况torch.Size([1171, 450])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# x轴最终预测结果
# x轴预测形状torch.Size([1171, 450])
# tensor([[0.7880, 0.7980, 0.7473,  ..., 0.7980, 0.8274, 0.8055],
#         [0.7880, 0.7980, 0.7472,  ..., 0.7979, 0.8274, 0.8056],
#         [0.7880, 0.7981, 0.7472,  ..., 0.7979, 0.8274, 0.8056],
#         ...,
#         [0.7882, 0.7992, 0.7477,  ..., 0.7991, 0.8274, 0.8049],
#         [0.7882, 0.7992, 0.7477,  ..., 0.7992, 0.8274, 0.8049],
#         [0.7882, 0.7993, 0.7477,  ..., 0.7993, 0.8274, 0.8049]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# y轴最终预测结果
# y轴预测形状torch.Size([1171, 450])
# ...
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# x轴最终预测结果
# x轴预测形状torch.Size([1531, 90])
# tensor([[0.8444, 0.9336, 0.9309,  ..., 0.9224, 0.8617, 0.9276],
#         [0.8443, 0.9336, 0.9309,  ..., 0.9224, 0.8617, 0.9276],
#         [0.8443, 0.9335, 0.9309,  ..., 0.9224, 0.8617, 0.9276],
#         ...,
#         [0.8443, 0.9337, 0.9313,  ..., 0.9223, 0.8615, 0.9275],
#         [0.8443, 0.9336, 0.9312,  ..., 0.9223, 0.8615, 0.9275],
#         [0.8443, 0.9336, 0.9312,  ..., 0.9223, 0.8615, 0.9274]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31804\913658689.py:243: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_y_pred_{index + 1}s_{i + 1}')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_31804\913658689.py:271: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f'complete_model_z_pred_{index + 1}s_{i + 1}')
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# 此时预测imf11输出形状torch.Size([1531, 90])
# y轴最终预测结果
# y轴预测形状torch.Size([1531, 90])
# tensor([[0.4412, 0.4291, 0.4341,  ..., 0.4331, 0.4346, 0.4737],
#         [0.4412, 0.4291, 0.4341,  ..., 0.4331, 0.4345, 0.4737],
#         [0.4412, 0.4291, 0.4341,  ..., 0.4331, 0.4345, 0.4737],
#         ...,
#         [0.4400, 0.4287, 0.4349,  ..., 0.4333, 0.4329, 0.4743],
#         [0.4401, 0.4288, 0.4350,  ..., 0.4334, 0.4329, 0.4743],
#         [0.4402, 0.4289, 0.4351,  ..., 0.4334, 0.4329, 0.4743]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1531, 90])
# 此时预测imf2输出形状torch.Size([1531, 90])
# 此时预测imf3输出形状torch.Size([1531, 90])
# 此时预测imf4输出形状torch.Size([1531, 90])
# 此时预测imf5输出形状torch.Size([1531, 90])
# 此时预测imf6输出形状torch.Size([1531, 90])
# 此时预测imf7输出形状torch.Size([1531, 90])
# 此时预测imf8输出形状torch.Size([1531, 90])
# 此时预测imf9输出形状torch.Size([1531, 90])
# 此时预测imf10输出形状torch.Size([1531, 90])
# z轴最终预测结果
# z轴预测形状torch.Size([1531, 90])
# tensor([[0.4061, 0.4311, 0.4354,  ..., 0.4386, 0.4319, 0.4396],
#         [0.4061, 0.4310, 0.4354,  ..., 0.4386, 0.4319, 0.4395],
#         [0.4061, 0.4310, 0.4354,  ..., 0.4386, 0.4319, 0.4395],
#         ...,
#         [0.4071, 0.4314, 0.4367,  ..., 0.4384, 0.4325, 0.4403],
#         [0.4070, 0.4314, 0.4367,  ..., 0.4384, 0.4325, 0.4403],
#         [0.4070, 0.4314, 0.4366,  ..., 0.4384, 0.4324, 0.4403]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小137790
# 9_MattSwift_fixations_sample_model_1s平均误差0.05523646082250057
# 现在对2s进行预测
# x轴真实情况torch.Size([1441, 180])
# y轴真实情况torch.Size([1441, 180])
# z轴真实情况torch.Size([1441, 180])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# x轴最终预测结果
# x轴预测形状torch.Size([1441, 180])
# tensor([[0.9473, 0.9686, 1.0016,  ..., 1.0275, 0.8626, 0.9416],
#         [0.9473, 0.9686, 1.0016,  ..., 1.0275, 0.8626, 0.9416],
#         [0.9473, 0.9686, 1.0016,  ..., 1.0275, 0.8626, 0.9417],
#         ...,
#         [0.9472, 0.9684, 1.0013,  ..., 1.0278, 0.8629, 0.9420],
#         [0.9474, 0.9686, 1.0015,  ..., 1.0280, 0.8631, 0.9419],
#         [0.9475, 0.9688, 1.0017,  ..., 1.0281, 0.8632, 0.9418]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# 此时预测imf11输出形状torch.Size([1441, 180])
# y轴最终预测结果
# y轴预测形状torch.Size([1441, 180])
# tensor([[0.3819, 0.3560, 0.3555,  ..., 0.4056, 0.3907, 0.4052],
#         [0.3819, 0.3560, 0.3556,  ..., 0.4055, 0.3907, 0.4052],
#         [0.3819, 0.3561, 0.3556,  ..., 0.4055, 0.3907, 0.4052],
#         ...,
#         [0.3812, 0.3560, 0.3546,  ..., 0.4047, 0.3907, 0.4047],
#         [0.3808, 0.3555, 0.3548,  ..., 0.4049, 0.3904, 0.4045],
#         [0.3805, 0.3551, 0.3549,  ..., 0.4051, 0.3901, 0.4044]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1441, 180])
# 此时预测imf2输出形状torch.Size([1441, 180])
# 此时预测imf3输出形状torch.Size([1441, 180])
# 此时预测imf4输出形状torch.Size([1441, 180])
# 此时预测imf5输出形状torch.Size([1441, 180])
# 此时预测imf6输出形状torch.Size([1441, 180])
# 此时预测imf7输出形状torch.Size([1441, 180])
# 此时预测imf8输出形状torch.Size([1441, 180])
# 此时预测imf9输出形状torch.Size([1441, 180])
# 此时预测imf10输出形状torch.Size([1441, 180])
# z轴最终预测结果
# z轴预测形状torch.Size([1441, 180])
# tensor([[0.4612, 0.4832, 0.4678,  ..., 0.4747, 0.4899, 0.4866],
#         [0.4611, 0.4832, 0.4678,  ..., 0.4747, 0.4898, 0.4867],
#         [0.4610, 0.4833, 0.4678,  ..., 0.4747, 0.4898, 0.4867],
#         ...,
#         [0.4631, 0.4830, 0.4688,  ..., 0.4745, 0.4895, 0.4858],
#         [0.4630, 0.4831, 0.4689,  ..., 0.4746, 0.4896, 0.4858],
#         [0.4628, 0.4833, 0.4690,  ..., 0.4747, 0.4896, 0.4859]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小259380
# 9_MattSwift_fixations_sample_model_2s平均误差0.07668685278159407
# 现在对3s进行预测
# x轴真实情况torch.Size([1351, 270])
# y轴真实情况torch.Size([1351, 270])
# z轴真实情况torch.Size([1351, 270])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# x轴最终预测结果
# x轴预测形状torch.Size([1351, 270])
# tensor([[0.8650, 0.8454, 0.8655,  ..., 0.8574, 0.8704, 0.8151],
#         [0.8651, 0.8454, 0.8655,  ..., 0.8574, 0.8704, 0.8151],
#         [0.8651, 0.8454, 0.8655,  ..., 0.8574, 0.8704, 0.8151],
#         ...,
#         [0.8646, 0.8454, 0.8651,  ..., 0.8575, 0.8706, 0.8157],
#         [0.8646, 0.8455, 0.8652,  ..., 0.8574, 0.8705, 0.8156],
#         [0.8647, 0.8455, 0.8652,  ..., 0.8573, 0.8704, 0.8156]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# 此时预测imf11输出形状torch.Size([1351, 270])
# y轴最终预测结果
# y轴预测形状torch.Size([1351, 270])
# tensor([[0.4025, 0.4089, 0.4089,  ..., 0.4064, 0.4208, 0.4021],
#         [0.4025, 0.4089, 0.4089,  ..., 0.4064, 0.4208, 0.4021],
#         [0.4025, 0.4089, 0.4089,  ..., 0.4064, 0.4208, 0.4021],
#         ...,
#         [0.4016, 0.4078, 0.4087,  ..., 0.4063, 0.4206, 0.4025],
#         [0.4018, 0.4078, 0.4090,  ..., 0.4066, 0.4204, 0.4023],
#         [0.4022, 0.4078, 0.4094,  ..., 0.4069, 0.4201, 0.4021]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1351, 270])
# 此时预测imf2输出形状torch.Size([1351, 270])
# 此时预测imf3输出形状torch.Size([1351, 270])
# 此时预测imf4输出形状torch.Size([1351, 270])
# 此时预测imf5输出形状torch.Size([1351, 270])
# 此时预测imf6输出形状torch.Size([1351, 270])
# 此时预测imf7输出形状torch.Size([1351, 270])
# 此时预测imf8输出形状torch.Size([1351, 270])
# 此时预测imf9输出形状torch.Size([1351, 270])
# 此时预测imf10输出形状torch.Size([1351, 270])
# z轴最终预测结果
# z轴预测形状torch.Size([1351, 270])
# tensor([[0.4401, 0.4489, 0.4716,  ..., 0.4551, 0.4280, 0.4590],
#         [0.4401, 0.4489, 0.4716,  ..., 0.4551, 0.4280, 0.4590],
#         [0.4401, 0.4489, 0.4716,  ..., 0.4551, 0.4281, 0.4591],
#         ...,
#         [0.4406, 0.4494, 0.4714,  ..., 0.4553, 0.4277, 0.4587],
#         [0.4405, 0.4494, 0.4714,  ..., 0.4553, 0.4278, 0.4587],
#         [0.4405, 0.4494, 0.4714,  ..., 0.4553, 0.4278, 0.4587]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小364770
# 9_MattSwift_fixations_sample_model_3s平均误差0.15552595179199352
# 现在对4s进行预测
# x轴真实情况torch.Size([1261, 360])
# y轴真实情况torch.Size([1261, 360])
# z轴真实情况torch.Size([1261, 360])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# x轴最终预测结果
# x轴预测形状torch.Size([1261, 360])
# tensor([[0.8611, 0.8747, 0.8085,  ..., 0.8806, 0.8117, 0.7681],
#         [0.8611, 0.8747, 0.8085,  ..., 0.8806, 0.8117, 0.7681],
#         [0.8611, 0.8747, 0.8085,  ..., 0.8806, 0.8117, 0.7681],
#         ...,
#         [0.8614, 0.8751, 0.8084,  ..., 0.8806, 0.8121, 0.7685],
#         [0.8614, 0.8751, 0.8084,  ..., 0.8806, 0.8121, 0.7685],
#         [0.8614, 0.8751, 0.8084,  ..., 0.8805, 0.8121, 0.7685]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# 此时预测imf11输出形状torch.Size([1261, 360])
# y轴最终预测结果
# y轴预测形状torch.Size([1261, 360])
# tensor([[0.3748, 0.3769, 0.3809,  ..., 0.3745, 0.3751, 0.3555],
#         [0.3748, 0.3769, 0.3809,  ..., 0.3745, 0.3751, 0.3555],
#         [0.3748, 0.3769, 0.3809,  ..., 0.3745, 0.3751, 0.3555],
#         ...,
#         [0.3743, 0.3771, 0.3813,  ..., 0.3743, 0.3747, 0.3554],
#         [0.3744, 0.3770, 0.3812,  ..., 0.3743, 0.3747, 0.3553],
#         [0.3745, 0.3769, 0.3811,  ..., 0.3742, 0.3747, 0.3553]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1261, 360])
# 此时预测imf2输出形状torch.Size([1261, 360])
# 此时预测imf3输出形状torch.Size([1261, 360])
# 此时预测imf4输出形状torch.Size([1261, 360])
# 此时预测imf5输出形状torch.Size([1261, 360])
# 此时预测imf6输出形状torch.Size([1261, 360])
# 此时预测imf7输出形状torch.Size([1261, 360])
# 此时预测imf8输出形状torch.Size([1261, 360])
# 此时预测imf9输出形状torch.Size([1261, 360])
# 此时预测imf10输出形状torch.Size([1261, 360])
# z轴最终预测结果
# z轴预测形状torch.Size([1261, 360])
# tensor([[0.4376, 0.4620, 0.4437,  ..., 0.4575, 0.4342, 0.4064],
#         [0.4375, 0.4619, 0.4437,  ..., 0.4575, 0.4341, 0.4063],
#         [0.4375, 0.4619, 0.4437,  ..., 0.4575, 0.4341, 0.4063],
#         ...,
#         [0.4378, 0.4624, 0.4440,  ..., 0.4578, 0.4342, 0.4065],
#         [0.4379, 0.4625, 0.4441,  ..., 0.4578, 0.4342, 0.4065],
#         [0.4379, 0.4624, 0.4441,  ..., 0.4578, 0.4342, 0.4066]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小453960
# 9_MattSwift_fixations_sample_model_4s平均误差0.20687524004931418
# 现在对5s进行预测
# x轴真实情况torch.Size([1171, 450])
# y轴真实情况torch.Size([1171, 450])
# z轴真实情况torch.Size([1171, 450])
# 开始预测x轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# x轴最终预测结果
# x轴预测形状torch.Size([1171, 450])
# tensor([[0.6888, 0.8833, 0.9057,  ..., 0.8509, 0.8965, 0.7991],
#         [0.6889, 0.8833, 0.9058,  ..., 0.8509, 0.8965, 0.7992],
#         [0.6889, 0.8833, 0.9058,  ..., 0.8509, 0.8964, 0.7992],
#         ...,
#         [0.6880, 0.8828, 0.9048,  ..., 0.8508, 0.8967, 0.7987],
#         [0.6879, 0.8829, 0.9049,  ..., 0.8509, 0.8965, 0.7988],
#         [0.6878, 0.8829, 0.9050,  ..., 0.8510, 0.8963, 0.7989]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------
# 开始预测y轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# 此时预测imf11输出形状torch.Size([1171, 450])
# y轴最终预测结果
# y轴预测形状torch.Size([1171, 450])
# tensor([[0.3580, 0.3448, 0.3821,  ..., 0.3778, 0.3731, 0.3860],
#         [0.3581, 0.3448, 0.3822,  ..., 0.3778, 0.3731, 0.3860],
#         [0.3581, 0.3448, 0.3822,  ..., 0.3778, 0.3731, 0.3860],
#         ...,
#         [0.3591, 0.3454, 0.3835,  ..., 0.3771, 0.3735, 0.3861],
#         [0.3591, 0.3453, 0.3833,  ..., 0.3771, 0.3736, 0.3861],
#         [0.3591, 0.3452, 0.3832,  ..., 0.3771, 0.3737, 0.3862]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# -------------------------------------
# 开始预测z轴
# 此时预测imf1输出形状torch.Size([1171, 450])
# 此时预测imf2输出形状torch.Size([1171, 450])
# 此时预测imf3输出形状torch.Size([1171, 450])
# 此时预测imf4输出形状torch.Size([1171, 450])
# 此时预测imf5输出形状torch.Size([1171, 450])
# 此时预测imf6输出形状torch.Size([1171, 450])
# 此时预测imf7输出形状torch.Size([1171, 450])
# 此时预测imf8输出形状torch.Size([1171, 450])
# 此时预测imf9输出形状torch.Size([1171, 450])
# 此时预测imf10输出形状torch.Size([1171, 450])
# z轴最终预测结果
# z轴预测形状torch.Size([1171, 450])
# tensor([[0.4795, 0.4971, 0.4598,  ..., 0.4665, 0.4905, 0.4920],
#         [0.4795, 0.4971, 0.4598,  ..., 0.4665, 0.4905, 0.4919],
#         [0.4795, 0.4971, 0.4598,  ..., 0.4666, 0.4905, 0.4919],
#         ...,
#         [0.4796, 0.4972, 0.4601,  ..., 0.4666, 0.4907, 0.4920],
#         [0.4795, 0.4972, 0.4601,  ..., 0.4666, 0.4907, 0.4920],
#         [0.4796, 0.4972, 0.4601,  ..., 0.4666, 0.4908, 0.4920]],
#        device='cuda:0', grad_fn=<SumBackward1>)
# 数据集大小526950
# 9_MattSwift_fixations_sample_model_5s平均误差0.2618030687888564
